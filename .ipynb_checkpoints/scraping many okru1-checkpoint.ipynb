# %%
import pandas as pd
import numpy as np
import glob
import os
from bs4 import BeautifulSoup

# %%
action_tubi_path = "/Users/timdunn/Downloads/tubi action.html"

# %%
def flatten(some_list):
    return [item for sublist in some_list for item in sublist]

# %%
def df_from_path(path):
    soup = soup_from_path(path)
    df = tubi_df(soup)
    df = df.dropna()
    return df.drop_duplicates()

# %%
def soup_from_path(path):
    with open(path) as fp:
        soup = BeautifulSoup(fp, 'html.parser')
    return soup

# %%
def a_tags_movies(soup):
    return soup.find_all('a', {"class": "web-content-tile__title"})

# %%
def url_title_a_tags(a_tags):
    title_urls = [{"url": a_tag['href'], "movie_title": a_tag.text } for a_tag in a_tags]
    return pd.DataFrame(data=title_urls)

# %%
def info_divs(soup):
    return soup.find_all('div', {"class": "web-content-tile__content-digest"})

# %%
def tubi_df(soup):
    data_dicts = [info_from_info_div(info_div) for info_div in info_divs(soup)]
    return pd.DataFrame(data=data_dicts)

# %%
def year_from_info_div(info_div):
    return info_div.find("div", {"class": "web-content-tile__year"}).text

# %%
def info_from_info_div(info_div):
    try:
        link_tag = info_div.find("a")
        return {
            "url": link_tag["href"],
            "movie_title": link_tag.text,
            "movie_year": year_from_info_div(info_div)
        }
    except:
        return {
            "url": pd.NA,
            "movie_title": pd.NA,
            "movie_year": pd.NA
        }

# %%
action_df = action_df.drop_duplicates()

# %%
tubi_paths = [
    "/Users/timdunn/Downloads/tubi anime.html",
    "/Users/timdunn/Downloads/tubi award.html",
    "/Users/timdunn/Downloads/tubi bollywood.html",
    "/Users/timdunn/Downloads/tubi classics.html",
    "/Users/timdunn/Downloads/tubi comedy.html",
    "/Users/timdunn/Downloads/tubi crime.html",
    "/Users/timdunn/Downloads/tubi cult.html",
    "/Users/timdunn/Downloads/tubi drama.html",
    "/Users/timdunn/Downloads/tubi faith.html",
    "/Users/timdunn/Downloads/tubi family.html",
    "/Users/timdunn/Downloads/tubi featured.html",
    "/Users/timdunn/Downloads/tubi foreign.html",
    "/Users/timdunn/Downloads/tubi holiday.html",
    "/Users/timdunn/Downloads/tubi indie.html",
    "/Users/timdunn/Downloads/tubi kids.html",
    "/Users/timdunn/Downloads/tubi lgbtq.html",
    "/Users/timdunn/Downloads/tubi lifestyle.html",
    "/Users/timdunn/Downloads/tubi martial arts.html",
    "/Users/timdunn/Downloads/tubi music.html",
    "/Users/timdunn/Downloads/tubi other spanish.html",
    "/Users/timdunn/Downloads/tubi popular.html",
    "/Users/timdunn/Downloads/tubi preschool.html",
    "/Users/timdunn/Downloads/tubi reality tv.html",
    "/Users/timdunn/Downloads/tubi sci fi.html",
    "/Users/timdunn/Downloads/tubi spanish family.html",
    "/Users/timdunn/Downloads/tubi sports.html",
    "/Users/timdunn/Downloads/tubi thriller.html",
    "/Users/timdunn/Downloads/tubi weekly.html",
    "/Users/timdunn/Downloads/tubi westerns.html"
]

# %%
def get_full_df_from_paths(paths):
    dfs = [df_from_path(path) for path in paths]
    for path in paths[1:]:
        df = pd.concat(dfs).drop_duplicates().reset_index(drop=True)
    return df

# %%
complete_tubi_df = get_full_df_from_paths(tubi_paths)

# %%
np.unique(complete_tubi_df["url"])
# Out:
# array(['https://tubitv.com/movies/11463/django-the-bastard?start=true',
#        'https://tubitv.com/movies/11478/if-you-meet-sartana-pray-for-your-death?start=true',
#        'https://tubitv.com/movies/11484/keoma?start=true', ...,
#        'https://tubitv.com/series/4834/talking-tom-and-friends?start=true',
#        'https://tubitv.com/series/4893/mcgraw-avenue?start=true',
#        'https://tubitv.com/series/908/the-dick-cavett-show?start=true'],
#       dtype=object)

# %%
searching_paths = [
    "/Volumes/Transcend/",
    "/Volumes/Transcend/2010s - 2020s movies/",
    "/Volumes/Transcend/2010s - 2020s new movies/",
    "/Volumes/Backup Plus/1940s-50s-60s movies/",
    "/Volumes/Backup Plus/1940s-50s-60s new movies/",
    "/Volumes/Elements/in between foreign films/",
    "/Volumes/Elements/1970s - 2000s movies /",
    "/Volumes/Elements/1970s - 2000s new movies /"
]

# %%
def listdir_nohidden(path):
    return glob.glob(os.path.join(path, '*'))

# %%
def get_files_from_paths(paths):
    return flatten([listdir_nohidden(path) for path in paths])

# %%
def unique_tubi_urls(df, paths_to_search):
    return df.loc[df["url"].isin(get_files_from_paths(paths_to_search))]

# %%
all_urls = np.unique(complete_tubi_df["url"])

# %%
filtering_clause = all_urls 
all_urls[]
# Out:
# 'https://tubitv.com/movies/11463/django-the-bastard?start=true'

# %%
filtering_thing = [(movie_title in path) for movie_title in  complete_tubi_df["movie_title"] for path in get_files_from_paths(tubi_paths)]

# %%
filtering_thing = [(movie_title in path) for movie_title in  complete_tubi_df["movie_title"] for path in paths]

# %%
def movie_has_a_path(movie_title, path):
    return movie_title.split("(")[0] in path

# %%
def movie_has_any_path(movie_title, paths):
    try:
        return any([movie_has_a_path(movie_title, path) for path in paths])
    except:
        return False

# %%
complete_tubi_df

# %%
real_filters = [not movie_has_any_path(movie_title, paths) for movie_title in complete_tubi_df["movie_title"]]

# %%
real_filters
# Out:
# [True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  ...]

# %%
complete_tubi_df

# %%
urls = np.unique(complete_tubi_df["url"][real_filters])

# %%
complete_tubi_df.loc[real_filters].to_csv("/Users/timdunn/Desktop/tubi_urls.csv", index=False)

# %%
any()

# %%
paths = get_files_from_paths(searching_paths)

# %%
tubi_paths
# Out:
# ['/Users/timdunn/Downloads/tubi anime.html',
#  '/Users/timdunn/Downloads/tubi award.html',
#  '/Users/timdunn/Downloads/tubi bollywood.html',
#  '/Users/timdunn/Downloads/tubi classics.html',
#  '/Users/timdunn/Downloads/tubi comedy.html',
#  '/Users/timdunn/Downloads/tubi crime.html',
#  '/Users/timdunn/Downloads/tubi cult.html',
#  '/Users/timdunn/Downloads/tubi drama.html',
#  '/Users/timdunn/Downloads/tubi faith.html',
#  '/Users/timdunn/Downloads/tubi family.html',
#  '/Users/timdunn/Downloads/tubi featured.html',
#  '/Users/timdunn/Downloads/tubi foreign.html',
#  '/Users/timdunn/Downloads/tubi holiday.html',
#  '/Users/timdunn/Downloads/tubi indie.html',
#  '/Users/timdunn/Downloads/tubi kids.html',
#  '/Users/timdunn/Downloads/tubi lgbtq.html',
#  '/Users/timdunn/Downloads/tubi lifestyle.html',
#  '/Users/timdunn/Downloads/tubi martial arts.html',
#  '/Users/timdunn/Downloads/tubi music.html',
#  '/Users/timdunn/Downloads/tubi other spanish.html',
#  '/Users/timdunn/Downloads/tubi popular.html',
#  '/Users/timdunn/Downloads/tubi preschool.html',
#  '/Users/timdunn/Downloads/tubi reality tv.html',
#  '/Users/timdunn/Downloads/tubi sci fi.html',
#  '/Users/timdunn/Downloads/tubi spanish family.html',
#  '/Users/timdunn/Downloads/tubi sports.html',
#  '/Users/timdunn/Downloads/tubi thriller.html',
#  '/Users/timdunn/Downloads/tubi weekly.html',
#  '/Users/timdunn/Downloads/tubi westerns.html']

# %%
paths
# Out:
# []

# %%
complete_tubi_df["movie_title"][0] in
# Out:
# 0         Saint Seiya Saintia Sho (Sub Esp)
# 1       Street Fighter: The New Challengers
# 2                   Future Card Buddy Fight
# 3                          Yu-Gi-Oh! VRAINS
# 4                    GGo Football (Español)
#                        ...
# 2394           The Trail Beyond (Colorized)
# 2395                              Heldorado
# 2396                                  Keoma
# 2397                              God's Gun
# 2398                      Riders of Destiny
# Name: movie_title, Length: 2399, dtype: object

# %%
def unique_urls(df, paths_to_search):
    df["url"]

# %%
divs = action_soup.find_all('div', {"class": "web-content-tile__content-digest"})

# %%
len(info_divs)
# Out:
# 995

# %%
path = "/Users/timdunn/Downloads/Feature Films _ Free Movies _ Free Download, Borrow and Streaming _ Internet Archive.html"
archives_soup = soup_from_path(path)

# %%
divs[0].find("div", {"class": "web-content-tile__year"}).text
# Out:
# '2018'
