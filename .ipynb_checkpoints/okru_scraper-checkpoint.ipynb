# %%
import pandas as pd
import numpy as np
import time
from fp.fp import FreeProxy

# %%
okru_url = "https://ok.ru/video"

# %%
CHROMEDRIVER_PATH = "/Users/timdunn/Downloads/chromedriver_mac_arm64/chromedriver"
WINDOW_SIZE = "1920,1080"

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By

# %%
def go_to_startpage(driver, start_url):
    driver.get(okru_url)
    return driver

# %%
def get_search_button(driver):
    element = driver.find_element(By.CLASS_NAME, "wrap-input__414z3")
    return element.find_element(By.TAG_NAME, "button")

# %%
# <h3 class="portlet_h_name_t">Weekly hits</h3>
def on_default_page(driver):
    try:
        return driver.find_element(By.CLASS_NAME, "portlet_h_name_t").text == "Weekly hits"
    except:
        return False

# %%
def popup_available(driver):
    try:
        popup(driver)
        return True
    except:
        return False

# %%
def popup(driver):
    return driver.find_element(By.CLASS_NAME, "close-button__akasx")

# %%
def close_popup(driver):
    if popup_available(driver):
        popup(driver).click()

# %%
def video_search(driver):
    return driver.find_element(By.XPATH, "//input[@placeholder='Video search']")

# %%
def search_movie(driver, movie_name, year):
    video_search(driver).send_keys("{} ({})".format(movie_name, year), Keys.RETURN)
#     driver.execute_script("arguments[0].click();", get_search_button(driver))
#     get_search_button(driver).click()
#     video_search(driver).send_keys("{} ({})".format(movie_name, year))
#     video_search(driver).submit()

# %%
def any_search_results(driver):
    try :
        return not (driver.find_element(By.CLASS_NAME, "stub-empty_t").text == 'No search results found')
    except:
        return True

# %%
def all_titles_movies(driver):
    return [movie.text for movie in driver.find_elements(By.CLASS_NAME, "video-card_duration")]

# %%
def movie_dict(element, tconst):
    return {
        "link title": get_movie_link_title(element),
        "link url": get_movie_url(element),
        "movie duration": get_movie_duration(element),
        "tconst": tconst
    }

# %%
def get_movie_link_title(element):
    try:
        return element.find_element(By.CLASS_NAME, "video-card_n").get_attribute("text")
    except:
#         print("movie title exception")
        return None

# %%
def get_movie_url(element):
    try:
#         print("movie url is", element.get_attribute("data-id"))
        return element.get_attribute("data-id")
    except:
#         print("movie url exception block")
        return None

# %%
def get_movie_duration(element):
    try:
#         print("movie duration is", element.find_element(By.CLASS_NAME, "video-card_duration").get_attribute("text"))
        return element.find_element(By.CLASS_NAME, "video-card_duration").text
    except:
#         print("movie duration exception block")
        return None

# %%
def get_all_movie_info(driver, tconst):
    try:
        return [movie_dict(element, tconst) for element in driver.find_elements(By.CLASS_NAME, "video-card")]
    except:
        print("all movie info except block")
        return []

# %%
def scroll_for_all_results(driver):
    movie_results = 0
    current_results = 1
    while movie_results != current_results:
        movie_results = current_results
        close_popup(driver)
        scroll_bottom(driver)
        time.sleep(3)
        current_results = len(all_titles_movies(driver))
    return current_results

# %%
def scroll_bottom(driver):
    driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")

# %%
def get_movie_search_results(driver, movie_name, year, tconst, instance_id, 
                             index, okru_url="https://ok.ru/video", all_data=[]):
    go_to_startpage(driver, okru_url)
    close_popup(driver)
    video_search(driver).clear()
    time.sleep(3)
    basic_results = all_titles_movies(driver)
    close_popup(driver)
    search_movie(driver, movie_name, year)
    close_popup(driver)
    if any_search_results(driver):
        close_popup(driver)
        time.sleep(5)
        if on_default_page(driver):
            print("on default page if")
            return "pending"
#             return restart_movie_search(driver, movie_name, year, tconst, okru_url, all_data)
        else:
            if index % 10 == 0:
                print("Went into else of instance {} and index {}".format(instance_id, index))
            scroll_for_all_results(driver)
            close_popup(driver)
            results = get_all_movie_info(driver, tconst)
            if len(results) == 0:
                return [{'link title': None,'link url': None,'movie duration': None,'tconst': tconst}]
            else:
                return results
    else:
        no_match_dict = {'link title': None,'link url': None,'movie duration': None,'tconst': tconst}
        return [no_match_dict]

# %%
def restart_movie_search(driver, movie_name, year, tconst, okru_url, all_data):
    try:
        driver.quit()
        driver = get_driver()
        go_to_startpage(driver, okru_url)
        close_popup(driver)
        return get_movie_search_results(driver, movie_name, year, tconst, okru_url, all_data)
    except:
        no_match_dict = {'link title': None,'link url': None,'movie duration': None,'tconst': tconst}
        return [no_match_dict]

# %%
from all_processes.update_movie_data import *

# %%
imdb_df = UpdateMovieData().get_latest_imdb()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [122], in <module>
# ----> 1 imdb_df = UpdateMovieData().get_latest_imdb()
#
# File ~/movie_project/all_processes/update_movie_data.py:16, in UpdateMovieData.get_latest_imdb(self)
#      14 def get_latest_imdb(self):
#      15     if self.imdb_file_not_updated():
# ---> 16         soup = self.go_to_imdb_page()
#      17         links = self.get_all_links(soup)
#      18         self.download_all_links(links)
#
# File ~/movie_project/all_processes/update_movie_data.py:51, in UpdateMovieData.go_to_imdb_page(self)
#      50 def go_to_imdb_page(self):
# ---> 51     return get_soup_url(self.imdb_data_url)
#
# NameError: name 'get_soup_url' is not defined

# %%
imdb_df = pd.read_csv("/Users/timdunn/Downloads/title.basics (1)-1.tsv", sep="\t")
# Out:
# /var/folders/z9/ml790yl90yj8nyc5j320wb4w0000gn/T/ipykernel_1520/1203546268.py:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   imdb_df = pd.read_csv("/Users/timdunn/Downloads/title.basics (1)-1.tsv", sep="\t")

# %%
imdb_df = imdb_df.loc[imdb_df["titleType"].isin(["movie", "tvMovie", "video"])]

# %%
dfs = [pd.read_csv(file_path) for file_path in listdir_nohidden("/Users/timdunn/Desktop/okru_checkpoints/already used/")]

# %%
okru_progress_path = "/Users/timdunn/Desktop/okru_progress.csv"
dfs.append(pd.read_csv(okru_progress_path))
final_df = pd.concat(dfs).drop_duplicates().reset_index(drop=True)

# %%
final_df.to_csv(okru_progress_path, index=False)

# %%
final_df.drop_duplicates(subset=['link url'])
# Out:
#                                                  link title      link url  \
# 0                                 Smile Before Death (1972)  3.444223e+12
# 1                                Эта весёлая планета (1973)           NaN
# 5         Привести в исполнение (1973) / Executive Actio...  1.824677e+12
# 6         Executive Action (1973) \tBurt Lancaster, Robe...  2.278275e+12
# 7         Burt Lancaster Executive Action (1973) DVDRip ...  1.642334e+12
# ...                                                     ...           ...
# 19611961  Альфред Бестер  Адам без Евы (Фантастический р...  1.242558e+12
# 19611962            Русский художник Анненков Юрий Павлович  5.558962e+09
# 19611963  NWO: Die EU Maske fällt. Erstes Land führt "TO...  1.099150e+10
# 19611964      Любовь удивляет / Hasard et l'amour, Le.1913.  1.550677e+12
# 19611965  Marilyn Manson • Marilyn Manson - The Mephisto...  8.340393e+11
#
#          movie duration     tconst  duration    year  \
# 0               1:28:15  tt0069301       NaN     NaN
# 1                   NaN  tt0070042       NaN     NaN
# 5               1:27:05  tt0070046       NaN     NaN
# 6               1:27:05  tt0070046       NaN     NaN
# 7               1:26:48  tt0070046       NaN     NaN
# ...                 ...        ...       ...     ...
# 19611961            NaN        NaN       0.0  1941.0
# 19611962            NaN        NaN       0.0     NaN
# 19611963            NaN        NaN       0.0     NaN
# 19611964            NaN        NaN       0.0  1913.0
# 19611965            NaN        NaN       0.0     NaN
#
#                                       searchable_movie_name
# 0                                                       NaN
# 1                                                       NaN
# 5                                                       NaN
# 6                                                       NaN
# 7                                                       NaN
# ...                                                     ...
# 19611961  альфред бестер адам без евы (фантастический ра...
# 19611962            русский художник анненков юрий павлович
# 19611963  nwo die eu maske fällt  erstes land führt tole...
# 19611964        любовь удивляет / hasard et lamour, le 1913
# 19611965  marilyn manson • marilyn manson  the mephistop...
#
# [4849578 rows x 7 columns]

# %%
from requirements import *

# %%
imdb_df.index

# %%
def get_driver():
    options = webdriver.ChromeOptions()
    options.add_argument("--headless")
    options.add_argument("--window-size=%s" % WINDOW_SIZE)
#     proxy = FreeProxy(elite=True).get()
#     options.add_argument('--proxy-server=%s' % proxy)
    return webdriver.Chrome(executable_path=CHROMEDRIVER_PATH, chrome_options=options)

# %%
def get_tconst_okru():
    return list(pd.read_csv("/Users/timdunn/Desktop/newokru.csv")["tconst"])

# %%
def filter_imdb(imdb_df, okru_tconst):
    return imdb_df.loc[~imdb_df["tconst"].isin(okru_tcosnt)]

# %%
imdb_df.loc[imdb_df["tconst"] == "tt0004256"]

# %%
other_data = []

# %%
def convert_data(the_data):
    the_data = flatten(the_data)
    the_data = list(filter(has_some_data, the_data))
#     print(the_data)
    return list(filter(lambda data: type(data) == dict, the_data))

# %%
from selenium.webdriver.chrome.options import Options

# %%
driver = get_driver()

# %%
driver = webdriver.Chrome(executable_path=CHROMEDRIVER_PATH, chrome_options=options)

# %%
def divide_chunks(l, n):
    for i in range(0, len(l), n):
        yield l[i:i + n]

# %%
def concating_okru_data():
    okru_progress_path = "/Users/timdunn/Desktop/okru_progress.csv"
    dfs = [pd.read_csv(file_path) for file_path in filtered_file_paths("/Users/timdunn/Desktop/okru_checkpoints/")]
    dfs.append(pd.read_csv(okru_progress_path))
    final_df = pd.concat(dfs).drop_duplicates().reset_index(drop=True)
#     final_df.to_csv(okru_progress_path)
    return final_df

# %%
def get_imdb_dfs(imdb_df, instances=5):
    okru_df = concating_okru_data()
    relevant_df = imdb_df.loc[~(imdb_df["runtimeMinutes"] == "\\N") & 
                              ~(imdb_df["tconst"].isin(okru_df["tconst"]))]
    return [relevant_df.loc[indexes] for indexes in divide_chunks(relevant_df.index, 
                                                                  round(relevant_df.index.size/instances))]

# %%
def save_okru_progress_to_df(instance_id, other_data, index):
    if len(other_data) > 0:
        pd.DataFrame(data=other_data).to_csv("/Users/timdunn/Desktop/okru_checkpoints/{}{}.csv".format(
            instance_id, index), index=False)

# %%
imdb_dfs = get_imdb_dfs(imdb_df)

# %%
def run_okru_scraper(relevant_df, instance_id, okru_url=okru_url):
    driver = get_driver()
    other_data = []
    try:
        for index, row in relevant_df.iterrows():
            next_data = get_movie_search_results(driver, row["primaryTitle"], row["startYear"], 
                                                 row["tconst"], instance_id, index, okru_url, other_data)
            other_data.append(next_data) 
            if (index % 100 == 0):
#             if (index % 10 == 0):
#                 print(next_data)
#                 print("The length of original data for {} and index {} is {}".format(instance_id, index, len(other_data)))
                print("The length of data for {} and index {} is {}".format(instance_id, index, len(convert_data(other_data))))
                save_okru_progress_to_df(instance_id, convert_data(other_data), index)
        save_okru_progress_to_df(instance_id, convert_data(other_data), index)
    except:
        save_okru_progress_to_df(instance_id, convert_data(other_data), "Exception")
        driver.quit()
        return convert_data(other_data)

# %%
def run_instances_okru_scraper(instances, imdb_df):
    imdb_dfs = get_imdb_dfs(imdb_df, instances)
    thread_list = list()
    for instance_id in range(instances):
        thread = threading.Thread(name='Test {}'.format(instance_id), target=run_okru_scraper, 
                                  args=(imdb_dfs[instance_id], instance_id))
        thread_list.append(thread)
        thread.start()
        print(thread.name + ' started!')
    for thread in thread_list:
        thread.join()

# %%
def listdir_nohidden(path):
    return glob.glob(os.path.join(path, '*'))

# %%
def combine_imdb_dfs():
    okru_df = pd.read_csv("/Users/timdunn/Desktop/okru_progress.csv")
    dfs = [pd.read_csv(file_path) for file_path in listdir_nohidden("/Users/timdunn/Desktop/okru_checkpoints/")]
    return pd.concat(flatten([dfs, okru_df])).drop_duplicates().reset_index(
        drop=True).to_csv("/Users/timdunn/Desktop/okru_progress.csv", index=False)

# %%
okru_data = concating_okru_data()

# %%
okru_data.to_csv("/Users/timdunn/Desktop/okru_progress.csv", index=False)

# %%
okru_data = okru_data.drop_duplicates(subset=["link url", "tconst"])

# %%
okru_data = pd.concat([okru_data, pd.read_csv("/Users/timdunn/Desktop/okru_progress.csv")]).drop_duplicates(subset=["link url", "tconst"])

# %%
import threading

# %%
import glob

# %%
import os

# %%
def file_has_data(file_path):
    return os.stat(file_path).st_size > 1

# %%
def filtered_file_paths(directory):
    return list(filter(file_has_data, listdir_nohidden(directory)))

# %%
paths = filtered_file_paths("/Users/timdunn/Desktop/okru_checkpoints/")

# %%
imdb_df.loc[9500:]

# %%
run_instances_okru_scraper(5, imdb_df)
# Out:
# KeyboardInterrupt

# %%
try:
    run_instances_okru_scraper(5, imdb_df.loc[9500:])
except:
    print("there was a major exception")
# Out:
# Exception in thread Test 4:
# Traceback (most recent call last):
#   File "/Users/timdunn/miniforge3/lib/python3.9/site-packages/urllib3/connection.py", line 174, in _new_conn
#     conn = connection.create_connection(
#   File "/Users/timdunn/miniforge3/lib/python3.9/site-packages/urllib3/util/connection.py", line 96, in create_connection
#     raise err
#   File "/Users/timdunn/miniforge3/lib/python3.9/site-packages/urllib3/util/connection.py", line 86, in create_connection
#     sock.connect(sa)
# ConnectionRefusedError: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/timdunn/miniforge3/lib/python3.9/site-packages/urllib3/connectionpool.py", line 699, in urlopen
#     httplib_response = self._make_request(
#   File "/Users/timdunn/miniforge3/lib/python3.9/site-packages/urllib3/connectionpool.py", line 394, in _make_request
#     conn.request(method, url, **httplib_request_kw)
#   File "/Users/timdunn/miniforge3/lib/python3.9/site-packages/urllib3/connection.py", line 239, in request
#     super(HTTPConnection, self).request(method, url, body=body, headers=headers)
#   File "/Users/timdunn/miniforge3/lib/python3.9/http/client.py", line 1279, in request
#     self._send_request(method, url, body, headers, encode_chunked)
#   File "/Users/timdunn/miniforge3/lib/python3.9/http/client.py", line 1325, in _send_request
#     self.endheaders(body, encode_chunked=encode_chunked)
#   File "/Users/timdunn/miniforge3/lib/python3.9/http/client.py", line 1274, in endheaders
#     self._send_output(message_body, encode_chunked=encode_chunked)
#   File "/Users/timdunn/miniforge3/lib/python3.9/http/client.py", line 1034, in _send_output
#     self.send(msg)
#   File "/Users/timdunn/miniforge3/lib/python3.9/http/client.py", line 974, in send
#     self.connect()
#   File "/Users/timdunn/miniforge3/lib/python3.9/site-packages/urllib3/connection.py", line 205, in connect
#     conn = self._new_conn()
#   File "/Users/timdunn/miniforge3/lib/python3.9/site-packages/urllib3/connection.py", line 186, in _new_conn
#     raise NewConnectionError(
# urllib3.exceptions.NewConnectionError: <urllib3.connection.HTTPConnection object at 0x17fe696a0>: Failed to establish a new connection: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/var/folders/z9/ml790yl90yj8nyc5j320wb4w0000gn/T/ipykernel_46589/3531318713.py", line 6, in run_okru_scraper
#   File "/var/folders/z9/ml790yl90yj8nyc5j320wb4w0000gn/T/ipykernel_46589/3510051943.py", line 21, in get_movie_search_results
#   File "/var/folders/z9/ml790yl90yj8nyc5j320wb4w0000gn/T/ipykernel_46589/3827795163.py", line 9, in scroll_for_all_results
#   File "/var/folders/z9/ml790yl90yj8nyc5j320wb4w0000gn/T/ipykernel_46589/1835705017.py", line 2, in all_titles_movies
#   File "/Users/timdunn/miniforge3/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py", line 890, in find_elements
#     return self.execute(Command.FIND_ELEMENTS, {
#   File "/Users/timdunn/miniforge3/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py", line 433, in execute
#     response = self.command_executor.execute(driver_command, params)
#   File "/Users/timdunn/miniforge3/lib/python3.9/site-packages/selenium/webdriver/remote/remote_connection.py", line 344, in execute
#     return self._request(command_info[0], url, body=data)
#   File "/Users/timdunn/miniforge3/lib/python3.9/site-packages/selenium/webdriver/remote/remote_connection.py", line 366, in _request
#     response = self._conn.request(method, url, body=body, headers=headers)
#   File "/Users/timdunn/miniforge3/lib/python3.9/site-packages/urllib3/request.py", line 78, in request
#     return self.request_encode_body(
#   File "/Users/timdunn/miniforge3/lib/python3.9/site-packages/urllib3/request.py", line 170, in request_encode_body
#     return self.urlopen(method, url, **extra_kw)
#   File "/Users/timdunn/miniforge3/lib/python3.9/site-packages/urllib3/poolmanager.py", line 375, in urlopen
#     response = conn.urlopen(method, u.request_uri, **kw)
#   File "/Users/timdunn/miniforge3/lib/python3.9/site-packages/urllib3/connectionpool.py", line 783, in urlopen
#     return self.urlopen(
#   File "/Users/timdunn/miniforge3/lib/python3.9/site-packages/urllib3/connectionpool.py", line 783, in urlopen
#     return self.urlopen(
#   File "/Users/timdunn/miniforge3/lib/python3.9/site-packages/urllib3/connectionpool.py", line 783, in urlopen
#     return self.urlopen(
#   File "/Users/timdunn/miniforge3/lib/python3.9/site-packages/urllib3/connectionpool.py", line 755, in urlopen
#     retries = retries.increment(
#   File "/Users/timdunn/miniforge3/lib/python3.9/site-packages/urllib3/util/retry.py", line 574, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPConnectionPool(host='localhost', port=52584): Max retries exceeded with url: /session/275d34636d94739f1bbab8fbc23edd22/elements (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x17fe696a0>: Failed to establish a new connection: [Errno 61] Connection refused'))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/timdunn/miniforge3/lib/python3.9/threading.py", line 973, in _bootstrap_inner
#     self.run()
#   File "/Users/timdunn/miniforge3/lib/python3.9/threading.py", line 910, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/z9/ml790yl90yj8nyc5j320wb4w0000gn/T/ipykernel_46589/3531318713.py", line 17, in run_okru_scraper
#   File "/var/folders/z9/ml790yl90yj8nyc5j320wb4w0000gn/T/ipykernel_46589/2239433442.py", line 3, in convert_data
# NameError: name 'has_some_data' is not defined
# Exception in thread Test 2:
# Traceback (most recent call last):
#   File "/Users/timdunn/miniforge3/lib/python3.9/site-packages/urllib3/connection.py", line 174, in _new_conn
#     conn = connection.create_connection(
#   File "/Users/timdunn/miniforge3/lib/python3.9/site-packages/urllib3/util/connection.py", line 96, in create_connection
#     raise err
#   File "/Users/timdunn/miniforge3/lib/python3.9/site-packages/urllib3/util/connection.py", line 86, in create_connection
#     sock.connect(sa)
# ConnectionRefusedError: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/timdunn/miniforge3/lib/python3.9/site-packages/urllib3/connectionpool.py", line 699, in urlopen
#     httplib_response = self._make_request(
#   File "/Users/timdunn/miniforge3/lib/python3.9/site-packages/urllib3/connectionpool.py", line 394, in _make_request
#     conn.request(method, url, **httplib_request_kw)
#   File "/Users/timdunn/miniforge3/lib/python3.9/site-packages/urllib3/connection.py", line 239, in request
#     super(HTTPConnection, self).request(method, url, body=body, headers=headers)
#   File "/Users/timdunn/miniforge3/lib/python3.9/http/client.py", line 1279, in request
#     self._send_request(method, url, body, headers, encode_chunked)
#   File "/Users/timdunn/miniforge3/lib/python3.9/http/client.py", line 1325, in _send_request
#     self.endheaders(body, encode_chunked=encode_chunked)
#   File "/Users/timdunn/miniforge3/lib/python3.9/http/client.py", line 1274, in endheaders
#     self._send_output(message_body, encode_chunked=encode_chunked)
#   File "/Users/timdunn/miniforge3/lib/python3.9/http/client.py", line 1034, in _send_output
#     self.send(msg)
#   File "/Users/timdunn/miniforge3/lib/python3.9/http/client.py", line 974, in send
#     self.connect()
#   File "/Users/timdunn/miniforge3/lib/python3.9/site-packages/urllib3/connection.py", line 205, in connect
#     conn = self._new_conn()
#   File "/Users/timdunn/miniforge3/lib/python3.9/site-packages/urllib3/connection.py", line 186, in _new_conn
#     raise NewConnectionError(
# urllib3.exceptions.NewConnectionError: <urllib3.connection.HTTPConnection object at 0x2b2a627f0>: Failed to establish a new connection: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/var/folders/z9/ml790yl90yj8nyc5j320wb4w0000gn/T/ipykernel_46589/3531318713.py", line 6, in run_okru_scraper
#   File "/var/folders/z9/ml790yl90yj8nyc5j320wb4w0000gn/T/ipykernel_46589/3510051943.py", line 7, in get_movie_search_results
#   File "/var/folders/z9/ml790yl90yj8nyc5j320wb4w0000gn/T/ipykernel_46589/1835705017.py", line 2, in all_titles_movies
#   File "/Users/timdunn/miniforge3/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py", line 890, in find_elements
#     return self.execute(Command.FIND_ELEMENTS, {
#   File "/Users/timdunn/miniforge3/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py", line 433, in execute
#     response = self.command_executor.execute(driver_command, params)
#   File "/Users/timdunn/miniforge3/lib/python3.9/site-packages/selenium/webdriver/remote/remote_connection.py", line 344, in execute
#     return self._request(command_info[0], url, body=data)
#   File "/Users/timdunn/miniforge3/lib/python3.9/site-packages/selenium/webdriver/remote/remote_connection.py", line 366, in _request
#     response = self._conn.request(method, url, body=body, headers=headers)
#   File "/Users/timdunn/miniforge3/lib/python3.9/site-packages/urllib3/request.py", line 78, in request
#     return self.request_encode_body(
#   File "/Users/timdunn/miniforge3/lib/python3.9/site-packages/urllib3/request.py", line 170, in request_encode_body
#     return self.urlopen(method, url, **extra_kw)
#   File "/Users/timdunn/miniforge3/lib/python3.9/site-packages/urllib3/poolmanager.py", line 375, in urlopen
#     response = conn.urlopen(method, u.request_uri, **kw)
#   File "/Users/timdunn/miniforge3/lib/python3.9/site-packages/urllib3/connectionpool.py", line 783, in urlopen
#     return self.urlopen(
#   File "/Users/timdunn/miniforge3/lib/python3.9/site-packages/urllib3/connectionpool.py", line 783, in urlopen
#     return self.urlopen(
#   File "/Users/timdunn/miniforge3/lib/python3.9/site-packages/urllib3/connectionpool.py", line 783, in urlopen
#     return self.urlopen(
#   File "/Users/timdunn/miniforge3/lib/python3.9/site-packages/urllib3/connectionpool.py", line 755, in urlopen
#     retries = retries.increment(
#   File "/Users/timdunn/miniforge3/lib/python3.9/site-packages/urllib3/util/retry.py", line 574, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPConnectionPool(host='localhost', port=52580): Max retries exceeded with url: /session/350618d999169d595396ea646a106c16/elements (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x2b2a627f0>: Failed to establish a new connection: [Errno 61] Connection refused'))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/timdunn/miniforge3/lib/python3.9/threading.py", line 973, in _bootstrap_inner
#     self.run()
#   File "/Users/timdunn/miniforge3/lib/python3.9/threading.py", line 910, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/z9/ml790yl90yj8nyc5j320wb4w0000gn/T/ipykernel_46589/3531318713.py", line 17, in run_okru_scraper
#   File "/var/folders/z9/ml790yl90yj8nyc5j320wb4w0000gn/T/ipykernel_46589/2239433442.py", line 3, in convert_data
# NameError: name 'has_some_data' is not defined
# Exception in thread Test 0:
# Traceback (most recent call last):
#   File "/Users/timdunn/miniforge3/lib/python3.9/site-packages/urllib3/connection.py", line 174, in _new_conn
#     conn = connection.create_connection(
#   File "/Users/timdunn/miniforge3/lib/python3.9/site-packages/urllib3/util/connection.py", line 96, in create_connection
#     raise err
#   File "/Users/timdunn/miniforge3/lib/python3.9/site-packages/urllib3/util/connection.py", line 86, in create_connection
#     sock.connect(sa)
# ConnectionRefusedError: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/timdunn/miniforge3/lib/python3.9/site-packages/urllib3/connectionpool.py", line 699, in urlopen
#     httplib_response = self._make_request(
#   File "/Users/timdunn/miniforge3/lib/python3.9/site-packages/urllib3/connectionpool.py", line 394, in _make_request
#     conn.request(method, url, **httplib_request_kw)
#   File "/Users/timdunn/miniforge3/lib/python3.9/site-packages/urllib3/connection.py", line 239, in request
#     super(HTTPConnection, self).request(method, url, body=body, headers=headers)
#   File "/Users/timdunn/miniforge3/lib/python3.9/http/client.py", line 1279, in request
#     self._send_request(method, url, body, headers, encode_chunked)
#   File "/Users/timdunn/miniforge3/lib/python3.9/http/client.py", line 1325, in _send_request
#     self.endheaders(body, encode_chunked=encode_chunked)
#   File "/Users/timdunn/miniforge3/lib/python3.9/http/client.py", line 1274, in endheaders
#     self._send_output(message_body, encode_chunked=encode_chunked)
#   File "/Users/timdunn/miniforge3/lib/python3.9/http/client.py", line 1034, in _send_output
#     self.send(msg)
#   File "/Users/timdunn/miniforge3/lib/python3.9/http/client.py", line 974, in send
#     self.connect()
#   File "/Users/timdunn/miniforge3/lib/python3.9/site-packages/urllib3/connection.py", line 205, in connect
#     conn = self._new_conn()
#   File "/Users/timdunn/miniforge3/lib/python3.9/site-packages/urllib3/connection.py", line 186, in _new_conn
#     raise NewConnectionError(
# urllib3.exceptions.NewConnectionError: <urllib3.connection.HTTPConnection object at 0x321b63370>: Failed to establish a new connection: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/var/folders/z9/ml790yl90yj8nyc5j320wb4w0000gn/T/ipykernel_46589/3531318713.py", line 6, in run_okru_scraper
#   File "/var/folders/z9/ml790yl90yj8nyc5j320wb4w0000gn/T/ipykernel_46589/3510051943.py", line 21, in get_movie_search_results
#   File "/var/folders/z9/ml790yl90yj8nyc5j320wb4w0000gn/T/ipykernel_46589/3827795163.py", line 7, in scroll_for_all_results
#   File "/var/folders/z9/ml790yl90yj8nyc5j320wb4w0000gn/T/ipykernel_46589/2661890195.py", line 2, in scroll_bottom
#   File "/Users/timdunn/miniforge3/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py", line 493, in execute_script
#     return self.execute(command, {
#   File "/Users/timdunn/miniforge3/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py", line 433, in execute
#     response = self.command_executor.execute(driver_command, params)
#   File "/Users/timdunn/miniforge3/lib/python3.9/site-packages/selenium/webdriver/remote/remote_connection.py", line 344, in execute
#     return self._request(command_info[0], url, body=data)
#   File "/Users/timdunn/miniforge3/lib/python3.9/site-packages/selenium/webdriver/remote/remote_connection.py", line 366, in _request
#     response = self._conn.request(method, url, body=body, headers=headers)
#   File "/Users/timdunn/miniforge3/lib/python3.9/site-packages/urllib3/request.py", line 78, in request
#     return self.request_encode_body(
#   File "/Users/timdunn/miniforge3/lib/python3.9/site-packages/urllib3/request.py", line 170, in request_encode_body
#     return self.urlopen(method, url, **extra_kw)
#   File "/Users/timdunn/miniforge3/lib/python3.9/site-packages/urllib3/poolmanager.py", line 375, in urlopen
#     response = conn.urlopen(method, u.request_uri, **kw)
#   File "/Users/timdunn/miniforge3/lib/python3.9/site-packages/urllib3/connectionpool.py", line 783, in urlopen
#     return self.urlopen(
#   File "/Users/timdunn/miniforge3/lib/python3.9/site-packages/urllib3/connectionpool.py", line 783, in urlopen
#     return self.urlopen(
#   File "/Users/timdunn/miniforge3/lib/python3.9/site-packages/urllib3/connectionpool.py", line 783, in urlopen
#     return self.urlopen(
#   File "/Users/timdunn/miniforge3/lib/python3.9/site-packages/urllib3/connectionpool.py", line 755, in urlopen
#     retries = retries.increment(
#   File "/Users/timdunn/miniforge3/lib/python3.9/site-packages/urllib3/util/retry.py", line 574, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPConnectionPool(host='localhost', port=52578): Max retries exceeded with url: /session/5e812d97ace738b761737a2aab36ad3f/execute/sync (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x321b63370>: Failed to establish a new connection: [Errno 61] Connection refused'))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/timdunn/miniforge3/lib/python3.9/threading.py", line 973, in _bootstrap_inner
#     self.run()
#   File "/Users/timdunn/miniforge3/lib/python3.9/threading.py", line 910, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/z9/ml790yl90yj8nyc5j320wb4w0000gn/T/ipykernel_46589/3531318713.py", line 17, in run_okru_scraper
#   File "/var/folders/z9/ml790yl90yj8nyc5j320wb4w0000gn/T/ipykernel_46589/2239433442.py", line 3, in convert_data
# NameError: name 'has_some_data' is not defined
# there was a major exception

# %%
try:
    run_instances_okru_scraper(5, imdb_df.loc[9500:])
except:
    print("there was a major exception")
# Out:
# there was a major exception

# %%
for num in range(5):
    try:
        run_instances_okru_scraper(6, imdb_df.loc[9500:])
    except:
        print("there was a major exception")
# Out:
# Test 0 started!
# Test 1 started!
# Test 2 started!
# Test 3 started!
# Test 4 started!
# Test 5 started!
# /var/folders/z9/ml790yl90yj8nyc5j320wb4w0000gn/T/ipykernel_46589/940046448.py:7: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   return webdriver.Chrome(executable_path=CHROMEDRIVER_PATH, chrome_options=options)
# /var/folders/z9/ml790yl90yj8nyc5j320wb4w0000gn/T/ipykernel_46589/940046448.py:7: DeprecationWarning: use options instead of chrome_options
#   return webdriver.Chrome(executable_path=CHROMEDRIVER_PATH, chrome_options=options)
# Went into else of instance 3 and index 2716310
# Went into else of instance 2 and index 399130
# Went into else of instance 4 and index 5394910
# Went into else of instance 5 and index 7187820
# Went into else of instance 2 and index 399140
# Went into else of instance 0 and index 21110
# Went into else of instance 1 and index 128730
# Went into else of instance 2 and index 399150
# Went into else of instance 1 and index 128750
# Went into else of instance 2 and index 399160
# Went into else of instance 0 and index 21340
# Went into else of instance 1 and index 128790
# Went into else of instance 1 and index 128810
# Went into else of instance 5 and index 7188000
# The length of data for 5 and index 7188000 is 407
# Went into else of instance 4 and index 5396210
# Went into else of instance 5 and index 7188130
# Went into else of instance 2 and index 399200
# The length of data for 2 and index 399200 is 453
# Went into else of instance 3 and index 2716400
# The length of data for 3 and index 2716400 is 1725
# Went into else of instance 0 and index 21380
# Went into else of instance 5 and index 7188390
# Went into else of instance 2 and index 399210
# Went into else of instance 2 and index 399320
# Went into else of instance 0 and index 21390
# Went into else of instance 2 and index 399330
# Went into else of instance 2 and index 399340
# Went into else of instance 0 and index 21400
# The length of data for 0 and index 21400 is 1422
# Went into else of instance 3 and index 2717230
# Went into else of instance 2 and index 399350
# Went into else of instance 0 and index 21410
# Went into else of instance 3 and index 2717450
# Went into else of instance 2 and index 399360
# Went into else of instance 0 and index 21420
# Went into else of instance 3 and index 2717600
# The length of data for 3 and index 2717600 is 2258
# Went into else of instance 3 and index 2718290
# Went into else of instance 2 and index 399380
# Went into else of instance 0 and index 21430
# Went into else of instance 1 and index 128980
# Went into else of instance 4 and index 5396230
# Went into else of instance 2 and index 399490
# Went into else of instance 0 and index 21440
# Went into else of instance 4 and index 5396310
# Went into else of instance 2 and index 399500
# The length of data for 2 and index 399500 is 1105
# Went into else of instance 1 and index 129050
# Went into else of instance 0 and index 21460
# Went into else of instance 1 and index 129060
# Went into else of instance 2 and index 399510
# Went into else of instance 3 and index 2718980
# Went into else of instance 4 and index 5396560
# Went into else of instance 4 and index 5396610
# Went into else of instance 2 and index 399530
# Went into else of instance 2 and index 399540
# Went into else of instance 4 and index 5396720
# Went into else of instance 1 and index 129170
# Went into else of instance 2 and index 399570
# Went into else of instance 2 and index 399580
# Went into else of instance 0 and index 21490
# Went into else of instance 3 and index 2719920
# Went into else of instance 2 and index 399600
# The length of data for 2 and index 399600 is 1344
# Went into else of instance 0 and index 21500
# The length of data for 0 and index 21500 is 2231
# Went into else of instance 2 and index 399630
# Went into else of instance 4 and index 5397030
# Went into else of instance 3 and index 2720420
# Went into else of instance 4 and index 5397170
# Went into else of instance 0 and index 21510
# Went into else of instance 5 and index 7188580
# Went into else of instance 1 and index 129180
# Went into else of instance 2 and index 399660
# Went into else of instance 0 and index 21520
# Went into else of instance 5 and index 7188660
# Went into else of instance 2 and index 399670
# Went into else of instance 2 and index 399680
# Went into else of instance 3 and index 2720480
# Went into else of instance 3 and index 2720540
# Went into else of instance 0 and index 21530
# Went into else of instance 4 and index 5398000
# The length of data for 4 and index 5398000 is 3889
# Went into else of instance 2 and index 399710
# Went into else of instance 1 and index 129200
# The length of data for 1 and index 129200 is 2920
# Went into else of instance 5 and index 7188830
# Went into else of instance 0 and index 21540
# Went into else of instance 3 and index 2720610
# Went into else of instance 3 and index 2720620
# Went into else of instance 3 and index 2720670
# Went into else of instance 5 and index 7188940
# Went into else of instance 0 and index 21550
# Went into else of instance 3 and index 2720750
# Went into else of instance 1 and index 129230
# Went into else of instance 0 and index 21560
# Went into else of instance 3 and index 2720780
# Went into else of instance 4 and index 5398650
# Went into else of instance 3 and index 2720820
# Went into else of instance 1 and index 129260
# Went into else of instance 0 and index 21570
# Went into else of instance 4 and index 5398670
# Went into else of instance 1 and index 129270
# Went into else of instance 4 and index 5398680
# Went into else of instance 1 and index 129280
# Went into else of instance 4 and index 5398700
# The length of data for 4 and index 5398700 is 5240
# Went into else of instance 1 and index 129290
# Went into else of instance 2 and index 399720
# Went into else of instance 3 and index 2721020
# Went into else of instance 3 and index 2721040
# Went into else of instance 0 and index 21590
# Went into else of instance 2 and index 399730
# Went into else of instance 3 and index 2721210
# Went into else of instance 1 and index 129300
# The length of data for 1 and index 129300 is 3725
# Went into else of instance 2 and index 399750
# Went into else of instance 3 and index 2721330
# Went into else of instance 1 and index 129310
# Went into else of instance 0 and index 21610
# Went into else of instance 1 and index 129320
# Went into else of instance 0 and index 21620
# Went into else of instance 4 and index 5398780
# Went into else of instance 1 and index 129330
# Went into else of instance 2 and index 399780
# Went into else of instance 0 and index 21630
# Went into else of instance 3 and index 2721930
# Went into else of instance 3 and index 2721940
# Went into else of instance 2 and index 399830
# Went into else of instance 0 and index 21660
# Went into else of instance 2 and index 399840
# Went into else of instance 1 and index 129360
# Went into else of instance 2 and index 399850
# Went into else of instance 0 and index 21670
# Went into else of instance 3 and index 2722320
# Went into else of instance 5 and index 7189050
# Went into else of instance 0 and index 21680
# Went into else of instance 3 and index 2722390
# Went into else of instance 2 and index 399870
# Went into else of instance 5 and index 7189120
# Went into else of instance 0 and index 21690
# Went into else of instance 3 and index 2722590
# Went into else of instance 2 and index 399900
# The length of data for 2 and index 399900 is 4738
# Went into else of instance 5 and index 7189150
# Went into else of instance 0 and index 21700
# The length of data for 0 and index 21700 is 4977
# Went into else of instance 1 and index 129380
# Went into else of instance 3 and index 2723030
# Went into else of instance 5 and index 7189180
# Went into else of instance 2 and index 399930
# Went into else of instance 5 and index 7189190
# Went into else of instance 5 and index 7189200
# The length of data for 5 and index 7189200 is 9768
# Went into else of instance 3 and index 2723260
# Went into else of instance 0 and index 21720
# Went into else of instance 2 and index 399950
# Went into else of instance 1 and index 129400
# The length of data for 1 and index 129400 is 5705
# Went into else of instance 0 and index 21730
# Went into else of instance 2 and index 399960
# Went into else of instance 5 and index 7189240
# Went into else of instance 5 and index 7189250
# Went into else of instance 1 and index 129410
# Went into else of instance 2 and index 399970
# Went into else of instance 3 and index 2724450
# Went into else of instance 1 and index 129420
# Went into else of instance 0 and index 21760
# Went into else of instance 4 and index 5398850
# Went into else of instance 1 and index 129440
# Went into else of instance 2 and index 400070
# Went into else of instance 4 and index 5399360
# Went into else of instance 4 and index 5399380
# Went into else of instance 3 and index 2725120
# Went into else of instance 2 and index 400080
# Went into else of instance 0 and index 21790
# Went into else of instance 3 and index 2725150
# Went into else of instance 2 and index 400090
# Went into else of instance 1 and index 129460
# Went into else of instance 2 and index 400100
# The length of data for 2 and index 400100 is 5685
# Went into else of instance 0 and index 21810
# Went into else of instance 1 and index 129480
# Went into else of instance 0 and index 21820
# Went into else of instance 1 and index 129500
# The length of data for 1 and index 129500 is 6774
# Went into else of instance 0 and index 21830
# Went into else of instance 1 and index 129510
# Went into else of instance 2 and index 400250
# Went into else of instance 2 and index 400260
# Went into else of instance 3 and index 2725470
# Went into else of instance 0 and index 21860
# Went into else of instance 2 and index 400290
# Went into else of instance 1 and index 129540
# Went into else of instance 3 and index 2725620
# Went into else of instance 1 and index 129550
# Went into else of instance 0 and index 21890
# Went into else of instance 3 and index 2725940
# Went into else of instance 0 and index 21900
# Went into else of instance 5 and index 7189500
# The length of data for 0 and index 21900 is 6498
# Went into else of instance 1 and index 129560
# The length of data for 5 and index 7189500 is 14540
# Went into else of instance 3 and index 2726070
# Went into else of instance 3 and index 2726530
# Went into else of instance 1 and index 129600
# The length of data for 1 and index 129600 is 7618
# Went into else of instance 0 and index 21920
# Went into else of instance 1 and index 129610
# Went into else of instance 0 and index 21930
# Went into else of instance 2 and index 400310
# Went into else of instance 1 and index 129620
# Went into else of instance 0 and index 21940
# Went into else of instance 4 and index 5399490
# Went into else of instance 2 and index 400330
# Went into else of instance 1 and index 129630
# Went into else of instance 4 and index 5399520
# Went into else of instance 0 and index 21950
# Went into else of instance 3 and index 2727430
# Went into else of instance 5 and index 7189750
# Went into else of instance 0 and index 21960
# Went into else of instance 0 and index 21970
# Went into else of instance 1 and index 129650
# Went into else of instance 2 and index 400390
# Went into else of instance 2 and index 400400
# The length of data for 2 and index 400400 is 7980
# Went into else of instance 0 and index 21980
# Went into else of instance 1 and index 129660
# Went into else of instance 4 and index 5400030
# Went into else of instance 1 and index 129670
# Went into else of instance 2 and index 400460
# Went into else of instance 0 and index 21990
# Went into else of instance 4 and index 5400050
# Went into else of instance 1 and index 129690
# Went into else of instance 0 and index 22000
# The length of data for 0 and index 22000 is 7317
# Went into else of instance 0 and index 22010
# Went into else of instance 0 and index 22020
# Went into else of instance 3 and index 2727520
# Went into else of instance 2 and index 400480
# Went into else of instance 1 and index 129890
# Went into else of instance 3 and index 2727530
# Went into else of instance 0 and index 22040
# Went into else of instance 3 and index 2727580
# Went into else of instance 0 and index 22050
# Went into else of instance 3 and index 2727970
# on default page if
# Went into else of instance 3 and index 2728000
# Went into else of instance 2 and index 400560
# The length of data for 3 and index 2728000 is 13887
# Went into else of instance 0 and index 22060
# Went into else of instance 1 and index 129990
# Went into else of instance 3 and index 2728040
# Went into else of instance 1 and index 130000
# The length of data for 1 and index 130000 is 9252
# Went into else of instance 3 and index 2728100
# The length of data for 3 and index 2728100 is 13911
# Went into else of instance 0 and index 22070
# Went into else of instance 5 and index 7189970
# Went into else of instance 1 and index 130010
# Went into else of instance 5 and index 7190000
# Went into else of instance 0 and index 22080
# Went into else of instance 1 and index 130020
# The length of data for 5 and index 7190000 is 19683
# Went into else of instance 2 and index 400600
# The length of data for 2 and index 400600 is 10503
# Went into else of instance 5 and index 7190040
# Went into else of instance 0 and index 22090
# Went into else of instance 0 and index 22100
# The length of data for 0 and index 22100 is 8395
# on default page if
# Went into else of instance 5 and index 7190150
# Went into else of instance 3 and index 2728390
# Went into else of instance 1 and index 130050
# Went into else of instance 0 and index 22110
# Went into else of instance 2 and index 400650
# Went into else of instance 3 and index 2728430
# Went into else of instance 1 and index 130060
# Went into else of instance 5 and index 7190250
# on default page if
# Went into else of instance 5 and index 7190260
# Went into else of instance 0 and index 22130
# Went into else of instance 2 and index 400690
# Went into else of instance 1 and index 130080
# Went into else of instance 2 and index 400700
# The length of data for 2 and index 400700 is 10944
# Went into else of instance 0 and index 22150
# Went into else of instance 1 and index 130110
# on default page if
# Went into else of instance 0 and index 22160
# Went into else of instance 2 and index 400720
# Went into else of instance 5 and index 7190280
# Went into else of instance 3 and index 2729070
# Went into else of instance 1 and index 130140
# Went into else of instance 0 and index 22170
# on default page if
# Went into else of instance 2 and index 400740
# Went into else of instance 0 and index 22180
# Went into else of instance 3 and index 2729110
# Went into else of instance 3 and index 2729210
# Went into else of instance 1 and index 130180
# Went into else of instance 5 and index 7190500
# The length of data for 5 and index 7190500 is 22618
# Went into else of instance 0 and index 22190
# Went into else of instance 5 and index 7190540
# Went into else of instance 1 and index 130200
# Went into else of instance 0 and index 22200
# The length of data for 1 and index 130200 is 10241
# Went into else of instance 5 and index 7190560
# The length of data for 0 and index 22200 is 8804
# Went into else of instance 2 and index 400790
# Went into else of instance 5 and index 7190580
# Went into else of instance 0 and index 22210
# Went into else of instance 5 and index 7190620
# Went into else of instance 3 and index 2730580
# Went into else of instance 1 and index 130230
# Went into else of instance 0 and index 22220
# Went into else of instance 3 and index 2730700
# The length of data for 3 and index 2730700 is 17102
# Went into else of instance 1 and index 130260
# Went into else of instance 0 and index 22230
# Went into else of instance 3 and index 2730800
# The length of data for 3 and index 2730800 is 17111
# Went into else of instance 5 and index 7190750
# Went into else of instance 1 and index 130270
# Went into else of instance 0 and index 22240
# Went into else of instance 3 and index 2731070
# Went into else of instance 0 and index 22250
# Went into else of instance 1 and index 130290
# Went into else of instance 0 and index 22260
# Went into else of instance 1 and index 130310
# Went into else of instance 0 and index 22270
# Went into else of instance 1 and index 130320
# Went into else of instance 0 and index 22280
# Went into else of instance 3 and index 2732840
# Went into else of instance 3 and index 2732950
# Went into else of instance 1 and index 130330
# Went into else of instance 5 and index 7191000
# The length of data for 5 and index 7191000 is 24543
# Went into else of instance 1 and index 130340
# Went into else of instance 5 and index 7191040
# Went into else of instance 0 and index 22300
# The length of data for 0 and index 22300 is 9997
# Went into else of instance 4 and index 5400100
# The length of data for 4 and index 5400100 is 22364
# Went into else of instance 1 and index 130350
# Went into else of instance 4 and index 5400130
# Went into else of instance 2 and index 400820
# Went into else of instance 0 and index 22310
# Went into else of instance 1 and index 130360
# Went into else of instance 4 and index 5400170
# Went into else of instance 1 and index 130370
# Went into else of instance 0 and index 22320
# Went into else of instance 4 and index 5400210
# Went into else of instance 5 and index 7191160
# Went into else of instance 4 and index 5400280
# Went into else of instance 3 and index 2734060
# Went into else of instance 0 and index 22350
# Went into else of instance 1 and index 130410
# Went into else of instance 5 and index 7191180
# Went into else of instance 2 and index 400900
# The length of data for 2 and index 400900 is 14985
# Went into else of instance 2 and index 400910
# Went into else of instance 0 and index 22370
# Went into else of instance 5 and index 7191290
# Went into else of instance 1 and index 130430
# Went into else of instance 2 and index 400930
# Went into else of instance 3 and index 2734730
# Went into else of instance 0 and index 22390
# Went into else of instance 4 and index 5400660
# Went into else of instance 3 and index 2734980
# Went into else of instance 2 and index 400960
# Went into else of instance 0 and index 22400
# The length of data for 0 and index 22400 is 10692
# Went into else of instance 2 and index 400970
# Went into else of instance 2 and index 400980
# Went into else of instance 3 and index 2735150
# Went into else of instance 3 and index 2735180
# Went into else of instance 1 and index 130500
# Went into else of instance 4 and index 5401510
# The length of data for 1 and index 130500 is 12668
# Went into else of instance 0 and index 22410
# Went into else of instance 3 and index 2735870
# Went into else of instance 5 and index 7191430
# Went into else of instance 1 and index 130520
# Went into else of instance 3 and index 2736230
# Went into else of instance 0 and index 22420
# Went into else of instance 3 and index 2736280
# Went into else of instance 0 and index 22430
# Went into else of instance 5 and index 7191460
# Went into else of instance 3 and index 2736610
# Went into else of instance 4 and index 5402600
# The length of data for 4 and index 5402600 is 25386
# Went into else of instance 2 and index 401050
# Went into else of instance 2 and index 401060
# Went into else of instance 0 and index 22440
# Went into else of instance 5 and index 7191480
# Went into else of instance 3 and index 2736740
# Went into else of instance 4 and index 5403460
# Went into else of instance 1 and index 130620
# Went into else of instance 1 and index 130630
# Went into else of instance 3 and index 2736850
# Went into else of instance 1 and index 130640
# Went into else of instance 2 and index 401110
# Went into else of instance 0 and index 22470
# Went into else of instance 4 and index 5403730
# Went into else of instance 2 and index 401130
# Went into else of instance 3 and index 2737060
# Went into else of instance 1 and index 130660
# Went into else of instance 5 and index 7191770
# Went into else of instance 3 and index 2737100
# The length of data for 3 and index 2737100 is 20618
# Went into else of instance 2 and index 401160
# Went into else of instance 5 and index 7191810
# Went into else of instance 4 and index 5404000
# Went into else of instance 0 and index 22480
# The length of data for 4 and index 5404000 is 26112
# Went into else of instance 1 and index 130700
# The length of data for 1 and index 130700 is 13629
# Went into else of instance 5 and index 7191930
# Went into else of instance 0 and index 22490
# Went into else of instance 5 and index 7192060
# Went into else of instance 1 and index 130770
# Went into else of instance 0 and index 22500
# The length of data for 0 and index 22500 is 12702
# Went into else of instance 5 and index 7192070
# Went into else of instance 2 and index 401330
# Went into else of instance 0 and index 22510
# Went into else of instance 0 and index 22520
# Went into else of instance 2 and index 401420
# Went into else of instance 2 and index 401430
# Went into else of instance 4 and index 5404330
# Went into else of instance 4 and index 5404340
# Went into else of instance 1 and index 130810
# Went into else of instance 4 and index 5404540
# Went into else of instance 5 and index 7192230
# Went into else of instance 0 and index 22540
# Went into else of instance 2 and index 401460
# Went into else of instance 2 and index 401480
# Went into else of instance 0 and index 22560
# Went into else of instance 4 and index 5405530
# Went into else of instance 1 and index 130850
# Went into else of instance 5 and index 7192450
# Went into else of instance 0 and index 22570
# Went into else of instance 4 and index 5406250
# Went into else of instance 1 and index 130860
# Went into else of instance 2 and index 401520
# Went into else of instance 2 and index 401540
# Went into else of instance 1 and index 130880
# Went into else of instance 0 and index 22580
# Went into else of instance 1 and index 130890
# Went into else of instance 2 and index 401550
# Went into else of instance 0 and index 22590
# Went into else of instance 3 and index 2737230
# Went into else of instance 2 and index 401560
# Went into else of instance 4 and index 5407590
# Went into else of instance 1 and index 130900
# Went into else of instance 5 and index 7192630
# The length of data for 1 and index 130900 is 14585
# Went into else of instance 3 and index 2737350
# Went into else of instance 0 and index 22600
# The length of data for 0 and index 22600 is 13092
# Went into else of instance 3 and index 2738290
# Went into else of instance 4 and index 5407850
# Went into else of instance 3 and index 2738820
# Went into else of instance 1 and index 130910
# Went into else of instance 2 and index 401590
# Went into else of instance 0 and index 22610
# Went into else of instance 1 and index 130920
# Went into else of instance 3 and index 2739140
# Went into else of instance 0 and index 22620
# Went into else of instance 2 and index 401620
# Went into else of instance 1 and index 130940
# Went into else of instance 2 and index 401630
# Went into else of instance 0 and index 22630
# Went into else of instance 1 and index 130950
# Went into else of instance 5 and index 7192790
# Went into else of instance 4 and index 5408350
# Went into else of instance 4 and index 5408370
# Went into else of instance 4 and index 5408440
# Went into else of instance 1 and index 130960
# Went into else of instance 0 and index 22650
# Went into else of instance 3 and index 2739410
# Went into else of instance 2 and index 401640
# Went into else of instance 0 and index 22660
# Went into else of instance 5 and index 7192880
# Went into else of instance 1 and index 130970
# Went into else of instance 4 and index 5408590
# Went into else of instance 2 and index 401680
# Went into else of instance 4 and index 5408660
# Went into else of instance 0 and index 22680
# Went into else of instance 1 and index 130990
# Went into else of instance 5 and index 7192960
# Went into else of instance 2 and index 401710
# Went into else of instance 0 and index 22690
# Went into else of instance 2 and index 401740
# Went into else of instance 0 and index 22720
# Went into else of instance 5 and index 7193020
# Went into else of instance 2 and index 401780
# Went into else of instance 3 and index 2739740
# Went into else of instance 3 and index 2739770
# Went into else of instance 5 and index 7193050
# Went into else of instance 2 and index 401830
# Went into else of instance 5 and index 7193100
# The length of data for 5 and index 7193100 is 34893
# Went into else of instance 0 and index 22730
# Went into else of instance 4 and index 5410610
# Went into else of instance 3 and index 2739820
# Went into else of instance 0 and index 22740
# Went into else of instance 3 and index 2739830
# Went into else of instance 4 and index 5410900
# The length of data for 4 and index 5410900 is 30423
# Went into else of instance 3 and index 2739850
# Went into else of instance 3 and index 2739870
# Went into else of instance 4 and index 5411160
# Went into else of instance 0 and index 22750
# Went into else of instance 2 and index 401910
# Went into else of instance 5 and index 7193240
# Went into else of instance 2 and index 401930
# Went into else of instance 1 and index 131040
# Went into else of instance 4 and index 5411450
# Went into else of instance 0 and index 22760
# Went into else of instance 5 and index 7193250
# Went into else of instance 1 and index 131060
# Went into else of instance 4 and index 5411590
# Went into else of instance 2 and index 401950
# Went into else of instance 4 and index 5411610
# Went into else of instance 0 and index 22770
# Went into else of instance 1 and index 131070
# Went into else of instance 5 and index 7193340
# Went into else of instance 4 and index 5411710
# Went into else of instance 1 and index 131080
# Went into else of instance 5 and index 7193350
# Went into else of instance 0 and index 22780
# Went into else of instance 5 and index 7193450
# Went into else of instance 1 and index 131090
# Went into else of instance 0 and index 22790
# Went into else of instance 5 and index 7193520
# Went into else of instance 4 and index 5414260
# Went into else of instance 1 and index 131130
# Went into else of instance 5 and index 7193560
# Went into else of instance 1 and index 131140
# Went into else of instance 4 and index 5414340
# Went into else of instance 1 and index 131160
# Went into else of instance 5 and index 7193810
# Went into else of instance 4 and index 5414360
# Went into else of instance 1 and index 131170
# Went into else of instance 0 and index 22830
# Went into else of instance 5 and index 7193930
# Went into else of instance 5 and index 7193960
# Went into else of instance 1 and index 131180
# Went into else of instance 0 and index 22840
# Went into else of instance 2 and index 402030
# Went into else of instance 1 and index 131190
# Went into else of instance 0 and index 22850
# Went into else of instance 4 and index 5415210
# Went into else of instance 2 and index 402040
# Went into else of instance 4 and index 5415220
# Went into else of instance 1 and index 131210
# Went into else of instance 0 and index 22860
# Went into else of instance 2 and index 402070
# Went into else of instance 4 and index 5415320
# Went into else of instance 1 and index 131280
# Went into else of instance 0 and index 22880
# Went into else of instance 4 and index 5415350
# Went into else of instance 1 and index 131290
# Went into else of instance 2 and index 402160
# Went into else of instance 0 and index 22890
# Went into else of instance 2 and index 402190
# Went into else of instance 1 and index 131300
# Went into else of instance 0 and index 22900
# The length of data for 1 and index 131300 is 17604
# The length of data for 0 and index 22900 is 16712
# Went into else of instance 2 and index 402220
# Went into else of instance 3 and index 2740560
# Went into else of instance 1 and index 131310
# Went into else of instance 3 and index 2740600
# The length of data for 3 and index 2740600 is 31065
# Went into else of instance 0 and index 22920
# Went into else of instance 1 and index 131320
# Went into else of instance 1 and index 131330
# Went into else of instance 1 and index 131340
# Went into else of instance 3 and index 2741220
# Went into else of instance 4 and index 5415400
# The length of data for 4 and index 5415400 is 33933
# Went into else of instance 0 and index 22930
# Went into else of instance 1 and index 131350
# Went into else of instance 1 and index 131360
# Went into else of instance 3 and index 2742030
# Went into else of instance 4 and index 5415980
# Went into else of instance 1 and index 131380
# Went into else of instance 0 and index 22950
# Went into else of instance 0 and index 22960
# Went into else of instance 3 and index 2742850
# Went into else of instance 0 and index 22970
# Went into else of instance 1 and index 131420
# Went into else of instance 4 and index 5416370
# Went into else of instance 0 and index 22980
# Went into else of instance 4 and index 5416400
# The length of data for 4 and index 5416400 is 34609
# Went into else of instance 4 and index 5416420
# Went into else of instance 5 and index 7194200
# The length of data for 5 and index 7194200 is 41099
# Went into else of instance 1 and index 131500
# The length of data for 1 and index 131500 is 18040
# Went into else of instance 3 and index 2743010
# Went into else of instance 0 and index 22990
# Went into else of instance 4 and index 5416500
# The length of data for 4 and index 5416500 is 34623
# Went into else of instance 1 and index 131520
# Went into else of instance 2 and index 402260
# Went into else of instance 4 and index 5416560
# Went into else of instance 1 and index 131530
# Went into else of instance 0 and index 23000
# The length of data for 0 and index 23000 is 17476
# Went into else of instance 2 and index 402270
# Went into else of instance 4 and index 5416570
# Went into else of instance 4 and index 5416630
# Went into else of instance 2 and index 402290
# Went into else of instance 4 and index 5416650
# Went into else of instance 2 and index 402300
# The length of data for 2 and index 402300 is 25808
# Went into else of instance 0 and index 23020
# Went into else of instance 1 and index 131550
# Went into else of instance 1 and index 131560
# Went into else of instance 4 and index 5417060
# Went into else of instance 0 and index 23030
# Went into else of instance 2 and index 402420
# Went into else of instance 3 and index 2743230
# Went into else of instance 0 and index 23050
# Went into else of instance 2 and index 402440
# Went into else of instance 1 and index 131570
# Went into else of instance 2 and index 402460
# Went into else of instance 0 and index 23070
# Went into else of instance 2 and index 402480
# Went into else of instance 3 and index 2743770
# Went into else of instance 0 and index 23080
# Went into else of instance 0 and index 23090
# Went into else of instance 2 and index 402500
# Went into else of instance 1 and index 131600
# The length of data for 2 and index 402500 is 27024
# The length of data for 1 and index 131600 is 20253
# Went into else of instance 3 and index 2744010
# Went into else of instance 0 and index 23100
# The length of data for 0 and index 23100 is 18058
# Went into else of instance 5 and index 7194300
# Went into else of instance 2 and index 402550
# Went into else of instance 0 and index 23120
# The length of data for 5 and index 7194300 is 43685
# Went into else of instance 1 and index 131630
# Went into else of instance 2 and index 402570
# Went into else of instance 3 and index 2744490
# Went into else of instance 3 and index 2744590
# Went into else of instance 0 and index 23130
# Went into else of instance 3 and index 2744930
# Went into else of instance 0 and index 23140
# Went into else of instance 5 and index 7194580
# Went into else of instance 2 and index 402610
# Went into else of instance 5 and index 7194620
# Went into else of instance 0 and index 23150
# Went into else of instance 2 and index 402630
# Went into else of instance 0 and index 23160
# Went into else of instance 5 and index 7194680
# Went into else of instance 1 and index 131640
# Went into else of instance 5 and index 7194690
# Went into else of instance 4 and index 5419240
# Went into else of instance 5 and index 7194700
# The length of data for 5 and index 7194700 is 44907
# Went into else of instance 0 and index 23170
# Went into else of instance 3 and index 2746510
# Went into else of instance 2 and index 402710
# Went into else of instance 1 and index 131650
# Went into else of instance 0 and index 23180
# Went into else of instance 3 and index 2746550
# Went into else of instance 4 and index 5419660
# Went into else of instance 0 and index 23210
# Went into else of instance 1 and index 131670
# Went into else of instance 4 and index 5419810
# Went into else of instance 3 and index 2746620
# Went into else of instance 1 and index 131680
# Went into else of instance 0 and index 23220
# Went into else of instance 2 and index 402740
# Went into else of instance 4 and index 5419960
# Went into else of instance 1 and index 131690
# Went into else of instance 4 and index 5419980
# Went into else of instance 0 and index 23230
# Went into else of instance 2 and index 402750
# Went into else of instance 1 and index 131700
# The length of data for 1 and index 131700 is 22312
# Went into else of instance 3 and index 2746710
# Went into else of instance 3 and index 2746820
# Went into else of instance 0 and index 23240
# Went into else of instance 1 and index 131710
# Went into else of instance 2 and index 402770
# Went into else of instance 0 and index 23250
# Went into else of instance 2 and index 402790
# Went into else of instance 3 and index 2746910
# Went into else of instance 4 and index 5420200
# The length of data for 4 and index 5420200 is 39492
# Went into else of instance 2 and index 402810
# Went into else of instance 4 and index 5420270
# Went into else of instance 3 and index 2747190
# Went into else of instance 0 and index 23260
# Went into else of instance 1 and index 131720
# Went into else of instance 3 and index 2747330
# Went into else of instance 4 and index 5420390
# Went into else of instance 0 and index 23270
# Went into else of instance 3 and index 2747480
# Went into else of instance 1 and index 131740
# Went into else of instance 4 and index 5420500
# The length of data for 4 and index 5420500 is 39816
# Went into else of instance 4 and index 5420510
# Went into else of instance 0 and index 23280
# Went into else of instance 3 and index 2747760
# Went into else of instance 2 and index 402870
# Went into else of instance 0 and index 23290
# Went into else of instance 2 and index 402910
# Went into else of instance 1 and index 131770
# Went into else of instance 4 and index 5422200
# Went into else of instance 5 and index 7194940
# The length of data for 4 and index 5422200 is 40696
# Went into else of instance 4 and index 5422250
# Went into else of instance 0 and index 23310
# Went into else of instance 2 and index 402920
# Went into else of instance 4 and index 5422540
# Went into else of instance 0 and index 23320
# Went into else of instance 1 and index 131780
# Went into else of instance 2 and index 402940
# Went into else of instance 1 and index 131790
# Went into else of instance 5 and index 7195130
# Went into else of instance 5 and index 7195140
# Went into else of instance 0 and index 23330
# Went into else of instance 2 and index 402970
# Went into else of instance 4 and index 5422950
# Went into else of instance 5 and index 7195170
# Went into else of instance 0 and index 23340
# Went into else of instance 2 and index 402980
# Went into else of instance 5 and index 7195370
# Went into else of instance 1 and index 131810
# Went into else of instance 4 and index 5423210
# Went into else of instance 4 and index 5423260
# Went into else of instance 5 and index 7195420
# Went into else of instance 0 and index 23360
# Went into else of instance 0 and index 23370
# Went into else of instance 2 and index 403010
# Went into else of instance 0 and index 23380
# Went into else of instance 1 and index 131830
# Went into else of instance 4 and index 5423390
# Went into else of instance 5 and index 7195490
# Went into else of instance 4 and index 5423440
# Went into else of instance 0 and index 23390
# Went into else of instance 2 and index 403020
# Went into else of instance 1 and index 131840
# Went into else of instance 5 and index 7195650
# Went into else of instance 0 and index 23400
# The length of data for 0 and index 23400 is 20787
# Went into else of instance 2 and index 403030
# Went into else of instance 1 and index 131870
# Went into else of instance 0 and index 23410
# Went into else of instance 5 and index 7195810
# Went into else of instance 2 and index 403040
# Went into else of instance 3 and index 2747970
# Went into else of instance 5 and index 7195820
# Went into else of instance 2 and index 403050
# Went into else of instance 0 and index 23430
# Went into else of instance 2 and index 403060
# Went into else of instance 2 and index 403070
# Went into else of instance 1 and index 131890
# Went into else of instance 4 and index 5426030
# Went into else of instance 1 and index 131910
# Went into else of instance 0 and index 23470
# Went into else of instance 4 and index 5426560
# Went into else of instance 4 and index 5426610
# Went into else of instance 1 and index 131930
# Went into else of instance 4 and index 5426660
# Went into else of instance 0 and index 23480
# Went into else of instance 1 and index 131940
# Went into else of instance 1 and index 131950
# Went into else of instance 4 and index 5426870
# Went into else of instance 0 and index 23490
# Went into else of instance 1 and index 131970
# Went into else of instance 2 and index 403110
# Went into else of instance 4 and index 5427040
# Went into else of instance 3 and index 2748250
# Went into else of instance 0 and index 23510
# Went into else of instance 2 and index 403120
# Went into else of instance 0 and index 23520
# Went into else of instance 5 and index 7195830
# Went into else of instance 0 and index 23530
# Went into else of instance 5 and index 7195850
# Went into else of instance 3 and index 2748440
# Went into else of instance 0 and index 23540
# Went into else of instance 3 and index 2748540
# Went into else of instance 3 and index 2748750
# Went into else of instance 0 and index 23550
# Went into else of instance 2 and index 403310
# Went into else of instance 5 and index 7195900
# The length of data for 5 and index 7195900 is 52105
# Went into else of instance 5 and index 7195920
# Went into else of instance 0 and index 23560
# Went into else of instance 5 and index 7195990
# Went into else of instance 0 and index 23570
# Went into else of instance 3 and index 2749140
# Went into else of instance 0 and index 23580
# Went into else of instance 5 and index 7196150
# Went into else of instance 1 and index 132030
# Went into else of instance 0 and index 23610
# Went into else of instance 5 and index 7196310
# Went into else of instance 3 and index 2750400
# The length of data for 3 and index 2750400 is 44369
# Went into else of instance 5 and index 7196320
# Went into else of instance 0 and index 23620
# Went into else of instance 2 and index 403360
# Went into else of instance 5 and index 7196330
# Went into else of instance 2 and index 403380
# Went into else of instance 0 and index 23630
# Went into else of instance 4 and index 5427730
# Went into else of instance 3 and index 2750540
# Went into else of instance 3 and index 2750550
# Went into else of instance 4 and index 5427980
# Went into else of instance 1 and index 132170
# Went into else of instance 4 and index 5428050
# Went into else of instance 3 and index 2750620
# Went into else of instance 1 and index 132200
# Went into else of instance 2 and index 403430
# The length of data for 1 and index 132200 is 28612
# Went into else of instance 0 and index 23650
# Went into else of instance 2 and index 403440
# Went into else of instance 4 and index 5428450
# Went into else of instance 3 and index 2750760
# Went into else of instance 0 and index 23660
# Went into else of instance 4 and index 5428590
# Went into else of instance 2 and index 403460
# Went into else of instance 4 and index 5428740
# Went into else of instance 0 and index 23670
# Went into else of instance 5 and index 7196530
# Went into else of instance 1 and index 132270
# Went into else of instance 0 and index 23680
# Went into else of instance 1 and index 132290
# Went into else of instance 4 and index 5429720
# Went into else of instance 2 and index 403500
# The length of data for 2 and index 403500 is 37653
# Went into else of instance 5 and index 7196560
# Went into else of instance 3 and index 2752930
# Went into else of instance 0 and index 23690
# Went into else of instance 1 and index 132320
# Went into else of instance 3 and index 2753230
# Went into else of instance 0 and index 23700
# The length of data for 0 and index 23700 is 22861
# Went into else of instance 3 and index 2753300
# The length of data for 3 and index 2753300 is 45748
# Went into else of instance 4 and index 5430790
# Went into else of instance 5 and index 7196760
# Went into else of instance 0 and index 23710
# Went into else of instance 5 and index 7196770
# Went into else of instance 3 and index 2753430
# Went into else of instance 4 and index 5430910
# Went into else of instance 1 and index 132350
# Went into else of instance 4 and index 5431150
# Went into else of instance 2 and index 403590
# Went into else of instance 5 and index 7196840
# Went into else of instance 5 and index 7196850
# Went into else of instance 3 and index 2753590
# Went into else of instance 2 and index 403600
# The length of data for 2 and index 403600 is 38841
# Went into else of instance 4 and index 5431210
# Went into else of instance 0 and index 23730
# Went into else of instance 5 and index 7197000
# The length of data for 5 and index 7197000 is 56954
# Went into else of instance 0 and index 23740
# Went into else of instance 1 and index 132380
# Went into else of instance 5 and index 7197060
# Went into else of instance 4 and index 5431500
# Went into else of instance 2 and index 403630
# The length of data for 4 and index 5431500 is 47751
# Went into else of instance 3 and index 2753850
# Went into else of instance 4 and index 5431520
# Went into else of instance 5 and index 7197070
# Went into else of instance 2 and index 403650
# Went into else of instance 1 and index 132440
# Went into else of instance 0 and index 23760
# Went into else of instance 2 and index 403660
# Went into else of instance 3 and index 2754040
# Went into else of instance 4 and index 5431640
# Went into else of instance 4 and index 5431680
# Went into else of instance 0 and index 23770
# Went into else of instance 2 and index 403700
# The length of data for 2 and index 403700 is 38949
# Went into else of instance 4 and index 5431690
# Went into else of instance 3 and index 2754150
# Went into else of instance 2 and index 403710
# Went into else of instance 4 and index 5431770
# Went into else of instance 0 and index 23780
# Went into else of instance 2 and index 403720
# Went into else of instance 2 and index 403730
# Went into else of instance 5 and index 7197510
# Went into else of instance 2 and index 403740
# Went into else of instance 4 and index 5433160
# Went into else of instance 3 and index 2755120
# Went into else of instance 2 and index 403750
# Went into else of instance 1 and index 132470
# Went into else of instance 4 and index 5433340
# Went into else of instance 0 and index 23800
# The length of data for 0 and index 23800 is 23663
# Went into else of instance 2 and index 403770
# Went into else of instance 1 and index 132480
# Went into else of instance 3 and index 2756360
# Went into else of instance 2 and index 403780
# Went into else of instance 5 and index 7197890
# Went into else of instance 1 and index 132500
# The length of data for 1 and index 132500 is 30995
# Went into else of instance 2 and index 403800
# The length of data for 2 and index 403800 is 39069
# Went into else of instance 4 and index 5433640
# Went into else of instance 1 and index 132510
# Went into else of instance 0 and index 23820
# Went into else of instance 3 and index 2756970
# Went into else of instance 5 and index 7198090
# Went into else of instance 1 and index 132520
# Went into else of instance 3 and index 2757010
# Went into else of instance 0 and index 23840
# Went into else of instance 3 and index 2757310
# Went into else of instance 5 and index 7198280
# Went into else of instance 4 and index 5434080
# Went into else of instance 4 and index 5434130
# Went into else of instance 5 and index 7198460
# Went into else of instance 3 and index 2757350
# Went into else of instance 2 and index 403820
# Went into else of instance 5 and index 7198590
# Went into else of instance 2 and index 403830
# Went into else of instance 5 and index 7198680
# Went into else of instance 3 and index 2757500
# The length of data for 3 and index 2757500 is 48099
# Went into else of instance 1 and index 132560
# Went into else of instance 0 and index 23880
# Went into else of instance 3 and index 2757820
# Went into else of instance 2 and index 403880
# Went into else of instance 0 and index 23890
# Went into else of instance 2 and index 403930
# Went into else of instance 2 and index 403960
# Went into else of instance 0 and index 23900
# The length of data for 0 and index 23900 is 24402
# Went into else of instance 3 and index 2758070
# Went into else of instance 0 and index 23920
# Went into else of instance 1 and index 132610
# Went into else of instance 5 and index 7199210
# Went into else of instance 0 and index 23930
# Went into else of instance 1 and index 132620
# Went into else of instance 2 and index 404020
# Went into else of instance 3 and index 2759180
# Went into else of instance 5 and index 7199390
# Went into else of instance 1 and index 132640
# Went into else of instance 5 and index 7199450
# Went into else of instance 1 and index 132650
# Went into else of instance 2 and index 404280
# Went into else of instance 2 and index 404290
# Went into else of instance 0 and index 23950
# Went into else of instance 2 and index 404310
# Went into else of instance 5 and index 7199680
# Went into else of instance 0 and index 23960
# Went into else of instance 1 and index 132670
# Went into else of instance 2 and index 404330
# Went into else of instance 1 and index 132680
# Went into else of instance 4 and index 5434320
# Went into else of instance 0 and index 23970
# Went into else of instance 2 and index 404360
# Went into else of instance 0 and index 23980
# Went into else of instance 2 and index 404370
# Went into else of instance 4 and index 5434530
# Went into else of instance 2 and index 404380
# Went into else of instance 0 and index 23990
# Went into else of instance 1 and index 132710
# Went into else of instance 5 and index 7199890
# Went into else of instance 1 and index 132760
# Went into else of instance 5 and index 7200000
# The length of data for 5 and index 7200000 is 62029
# Went into else of instance 2 and index 404400
# The length of data for 2 and index 404400 is 42096
# Went into else of instance 0 and index 24000
# The length of data for 0 and index 24000 is 25431
# Went into else of instance 1 and index 132770
# Went into else of instance 0 and index 24010
# Went into else of instance 2 and index 404450
# Went into else of instance 4 and index 5434700
# Went into else of instance 0 and index 24020
# The length of data for 4 and index 5434700 is 52592
# Went into else of instance 2 and index 404460
# Went into else of instance 4 and index 5434740
# Went into else of instance 5 and index 7200150
# Went into else of instance 2 and index 404470
# Went into else of instance 0 and index 24030
# Went into else of instance 2 and index 404510
# Went into else of instance 5 and index 7200160
# Went into else of instance 2 and index 404560
# Went into else of instance 1 and index 132790
# Went into else of instance 0 and index 24050
# Went into else of instance 3 and index 2759400
# The length of data for 3 and index 2759400 is 52221
# Went into else of instance 0 and index 24060
# Went into else of instance 5 and index 7200260
# Went into else of instance 2 and index 404700
# The length of data for 2 and index 404700 is 42440
# Went into else of instance 1 and index 132830
# Went into else of instance 4 and index 5435270
# Went into else of instance 0 and index 24070
# Went into else of instance 2 and index 404720
# Went into else of instance 5 and index 7200300
# The length of data for 5 and index 7200300 is 63513
# Went into else of instance 4 and index 5435400
# The length of data for 4 and index 5435400 is 53681
# Went into else of instance 1 and index 132860
# Went into else of instance 4 and index 5435410
# Went into else of instance 3 and index 2760070
# Went into else of instance 0 and index 24080
# Went into else of instance 3 and index 2760130
# Went into else of instance 1 and index 132870
# Went into else of instance 0 and index 24090
# Went into else of instance 2 and index 404760
# Went into else of instance 0 and index 24100
# ...
# Went into else of instance 1 and index 162920
# Went into else of instance 4 and index 5713430
# Went into else of instance 5 and index 7357940
# Went into else of instance 2 and index 442660
# Went into else of instance 3 and index 3013400
# The length of data for 3 and index 3013400 is 56284
# Went into else of instance 1 and index 162930
# on default page if
# on default page if
# Went into else of instance 0 and index 35630
# Went into else of instance 3 and index 3013420
# Went into else of instance 1 and index 162940
# Went into else of instance 3 and index 3013440
# Went into else of instance 3 and index 3013480
# Went into else of instance 2 and index 442700
# The length of data for 2 and index 442700 is 56657
# on default page if
# on default page if
# Went into else of instance 0 and index 35640
# Went into else of instance 2 and index 442720
# Went into else of instance 3 and index 3013760
# Went into else of instance 1 and index 162980
# on default page if
# on default page if
# Went into else of instance 5 and index 7358250
# on default page if
# on default page if
# Went into else of instance 0 and index 35660
# Went into else of instance 3 and index 3013850
# Went into else of instance 5 and index 7358390
# Went into else of instance 1 and index 163030
# Went into else of instance 0 and index 35670
# Went into else of instance 1 and index 163040
# Went into else of instance 4 and index 5713810
# Went into else of instance 3 and index 3014120
# Went into else of instance 5 and index 7365260
# Went into else of instance 3 and index 3014220
# Went into else of instance 0 and index 35680
# Went into else of instance 5 and index 7365280
# Went into else of instance 5 and index 7365350
# Went into else of instance 4 and index 5714450
# Went into else of instance 5 and index 7365360
# Went into else of instance 3 and index 3014840
# Went into else of instance 2 and index 442840
# Went into else of instance 5 and index 7365480
# Went into else of instance 0 and index 35700
# The length of data for 0 and index 35700 is 27340
# Went into else of instance 1 and index 163120
# Went into else of instance 2 and index 442890
# on default page if
# on default page if
# on default page if
# on default page if
# Went into else of instance 5 and index 7365790
# on default page if
# on default page if
# on default page if
# on default page if
# Went into else of instance 0 and index 35710
# Went into else of instance 2 and index 442910
# Went into else of instance 3 and index 3014930
# Went into else of instance 1 and index 163160
# Went into else of instance 4 and index 5716060
# Went into else of instance 4 and index 5716080
# Went into else of instance 2 and index 442940
# Went into else of instance 3 and index 3015180
# Went into else of instance 0 and index 35720
# Went into else of instance 3 and index 3015220
# Went into else of instance 3 and index 3015230
# Went into else of instance 3 and index 3015370
# Went into else of instance 0 and index 35730
# Went into else of instance 4 and index 5716480
# Went into else of instance 4 and index 5716530
# Went into else of instance 3 and index 3015560
# Went into else of instance 2 and index 442980
# Went into else of instance 2 and index 442990
# Went into else of instance 0 and index 35740
# Went into else of instance 4 and index 5716740
# on default page if
# Went into else of instance 0 and index 35750
# Went into else of instance 4 and index 5716890
# Went into else of instance 1 and index 163240
# Went into else of instance 4 and index 5716980
# Went into else of instance 2 and index 443140
# Went into else of instance 4 and index 5717120
# Went into else of instance 2 and index 443180
# Went into else of instance 4 and index 5717140
# Went into else of instance 2 and index 443220
# Went into else of instance 1 and index 163280
# Went into else of instance 0 and index 35770
# Went into else of instance 2 and index 443230
# Went into else of instance 1 and index 163300
# The length of data for 1 and index 163300 is 56710
# Went into else of instance 4 and index 5717170
# Went into else of instance 0 and index 35780
# Went into else of instance 2 and index 443240
# Went into else of instance 0 and index 35790
# Went into else of instance 4 and index 5717510
# Went into else of instance 1 and index 163330
# Went into else of instance 3 and index 3016090
# Went into else of instance 1 and index 163350
# Went into else of instance 4 and index 5718000
# The length of data for 4 and index 5718000 is 66882
# Went into else of instance 3 and index 3016420
# Went into else of instance 1 and index 163390
# Went into else of instance 3 and index 3017180
# Went into else of instance 5 and index 7365970
# Went into else of instance 0 and index 35820
# Went into else of instance 2 and index 443360
# Went into else of instance 3 and index 3018460
# Went into else of instance 1 and index 163420
# Went into else of instance 5 and index 7366130
# Went into else of instance 3 and index 3019400
# The length of data for 3 and index 3019400 is 60108
# Went into else of instance 1 and index 163430
# Went into else of instance 2 and index 443370
# Went into else of instance 0 and index 35830
# Went into else of instance 3 and index 3019860
# Went into else of instance 2 and index 443390
# Went into else of instance 4 and index 5718970
# Went into else of instance 1 and index 163480
# Went into else of instance 5 and index 7366360
# Went into else of instance 2 and index 443400
# Went into else of instance 0 and index 35850
# The length of data for 2 and index 443400 is 60642
# Went into else of instance 4 and index 5719120
# Went into else of instance 3 and index 3020100
# Went into else of instance 5 and index 7366530
# The length of data for 3 and index 3020100 is 60795
# Went into else of instance 0 and index 35860
# Went into else of instance 5 and index 7366750
# Went into else of instance 1 and index 163530
# Went into else of instance 3 and index 3020290
# Went into else of instance 2 and index 443440
# Went into else of instance 5 and index 7366890
# Went into else of instance 1 and index 163680
# Went into else of instance 4 and index 5719560
# Went into else of instance 2 and index 443470
# Went into else of instance 2 and index 443480
# Went into else of instance 3 and index 3021540
# Went into else of instance 0 and index 35890
# Went into else of instance 1 and index 163720
# Went into else of instance 2 and index 443490
# Went into else of instance 0 and index 35900
# The length of data for 0 and index 35900 is 29226
# Went into else of instance 3 and index 3022640
# Went into else of instance 0 and index 35910
# Went into else of instance 3 and index 3023000
# Went into else of instance 5 and index 7367450
# The length of data for 3 and index 3023000 is 62083
# Went into else of instance 0 and index 35920
# Went into else of instance 1 and index 163790
# Went into else of instance 1 and index 163810
# Went into else of instance 2 and index 443540
# Went into else of instance 3 and index 3023620
# Went into else of instance 1 and index 163880
# Went into else of instance 0 and index 35930
# Went into else of instance 1 and index 163900
# The length of data for 1 and index 163900 is 56835
# Went into else of instance 5 and index 7367630
# Went into else of instance 1 and index 163910
# Went into else of instance 2 and index 443590
# Went into else of instance 3 and index 3023810
# Went into else of instance 0 and index 35940
# Went into else of instance 1 and index 163930
# Went into else of instance 1 and index 163950
# Went into else of instance 0 and index 35950
# Went into else of instance 1 and index 163970
# Went into else of instance 2 and index 443630
# Went into else of instance 2 and index 443640
# Went into else of instance 1 and index 163990
# Went into else of instance 5 and index 7368090
# Went into else of instance 0 and index 35960
# Went into else of instance 2 and index 443650
# Went into else of instance 0 and index 35970
# Went into else of instance 1 and index 164020
# Went into else of instance 4 and index 5719750
# Went into else of instance 4 and index 5719790
# Went into else of instance 1 and index 164050
# Went into else of instance 4 and index 5719840
# Went into else of instance 1 and index 164060
# Went into else of instance 1 and index 164070
# Went into else of instance 5 and index 7368270
# Went into else of instance 0 and index 35990
# Went into else of instance 1 and index 164080
# Went into else of instance 4 and index 5719930
# Went into else of instance 3 and index 3024440
# Went into else of instance 1 and index 164110
# Went into else of instance 0 and index 36000
# The length of data for 0 and index 36000 is 30922
# Went into else of instance 1 and index 164120
# Went into else of instance 1 and index 164130
# Went into else of instance 5 and index 7368640
# Went into else of instance 3 and index 3024830
# Went into else of instance 5 and index 7368660
# Went into else of instance 3 and index 3024870
# Went into else of instance 3 and index 3024890
# Went into else of instance 1 and index 164150
# Went into else of instance 3 and index 3025480
# Went into else of instance 0 and index 36020
# Went into else of instance 4 and index 5720110
# Went into else of instance 4 and index 5720130
# Went into else of instance 5 and index 7368800
# Went into else of instance 3 and index 3026690
# Went into else of instance 1 and index 164190
# The length of data for 5 and index 7368800 is 79287
# Went into else of instance 0 and index 36040
# Went into else of instance 5 and index 7368910
# Went into else of instance 5 and index 7368990
# Went into else of instance 4 and index 5720280
# Went into else of instance 2 and index 443700
# The length of data for 2 and index 443700 is 65834
# Went into else of instance 0 and index 36050
# Went into else of instance 4 and index 5720310
# Went into else of instance 2 and index 443710
# Went into else of instance 0 and index 36060
# Went into else of instance 3 and index 3027480
# Went into else of instance 1 and index 164270
# Went into else of instance 1 and index 164290
# Went into else of instance 5 and index 7369060
# Went into else of instance 1 and index 164300
# The length of data for 1 and index 164300 is 56950
# Went into else of instance 4 and index 5721040
# Went into else of instance 0 and index 36070
# Went into else of instance 1 and index 164330
# Went into else of instance 5 and index 7369410
# Went into else of instance 0 and index 36090
# Went into else of instance 5 and index 7369540
# Went into else of instance 3 and index 3028170
# Went into else of instance 3 and index 3028240
# Went into else of instance 1 and index 164390
# Went into else of instance 3 and index 3028260
# Went into else of instance 4 and index 5721980
# Went into else of instance 5 and index 7369680
# Went into else of instance 0 and index 36100
# The length of data for 0 and index 36100 is 32459
# Went into else of instance 3 and index 3028280
# Went into else of instance 1 and index 164410
# Went into else of instance 4 and index 5722290
# Went into else of instance 0 and index 36120
# Went into else of instance 1 and index 164450
# Went into else of instance 3 and index 3028750
# Went into else of instance 0 and index 36130
# Went into else of instance 3 and index 3029170
# Went into else of instance 0 and index 36140
# Went into else of instance 1 and index 164480
# Went into else of instance 5 and index 7370700
# Went into else of instance 0 and index 36150
# The length of data for 5 and index 7370700 is 81158
# Went into else of instance 4 and index 5722860
# Went into else of instance 1 and index 164540
# Went into else of instance 0 and index 36160
# Went into else of instance 2 and index 443750
# Went into else of instance 5 and index 7370790
# Went into else of instance 4 and index 5723090
# Went into else of instance 5 and index 7370840
# Went into else of instance 0 and index 36170
# Went into else of instance 1 and index 164580
# Went into else of instance 3 and index 3030180
# Went into else of instance 0 and index 36180
# Went into else of instance 2 and index 443870
# Went into else of instance 3 and index 3030270
# Went into else of instance 3 and index 3030390
# Went into else of instance 1 and index 164600
# The length of data for 1 and index 164600 is 57871
# Went into else of instance 0 and index 36190
# Went into else of instance 4 and index 5724600
# Went into else of instance 2 and index 443880
# The length of data for 4 and index 5724600 is 75108
# Went into else of instance 1 and index 164620
# Went into else of instance 0 and index 36210
# Went into else of instance 1 and index 164640
# Went into else of instance 1 and index 164650
# Went into else of instance 4 and index 5724810
# Went into else of instance 2 and index 443910
# Went into else of instance 0 and index 36220
# Went into else of instance 4 and index 5725050
# Went into else of instance 4 and index 5725180
# Went into else of instance 3 and index 3031770
# Went into else of instance 1 and index 164700
# The length of data for 1 and index 164700 is 58016
# Went into else of instance 0 and index 36240
# Went into else of instance 4 and index 5725300
# The length of data for 4 and index 5725300 is 76760
# Went into else of instance 0 and index 36250
# Went into else of instance 3 and index 3032440
# Went into else of instance 5 and index 7371600
# Went into else of instance 4 and index 5725310
# The length of data for 5 and index 7371600 is 83405
# Went into else of instance 4 and index 5725340
# Went into else of instance 0 and index 36260
# Went into else of instance 2 and index 443990
# Went into else of instance 5 and index 7371820
# Went into else of instance 0 and index 36270
# Went into else of instance 4 and index 5725590
# Went into else of instance 5 and index 7371940
# Went into else of instance 5 and index 7371950
# Went into else of instance 4 and index 5725710
# Went into else of instance 3 and index 3033260
# Went into else of instance 2 and index 444010
# Went into else of instance 4 and index 5725920
# Went into else of instance 4 and index 5726250
# Went into else of instance 0 and index 36300
# The length of data for 0 and index 36300 is 34206
# Went into else of instance 5 and index 7372180
# Went into else of instance 2 and index 444020
# Went into else of instance 2 and index 444030
# Went into else of instance 0 and index 36310
# Went into else of instance 2 and index 444040
# Went into else of instance 0 and index 36320
# Went into else of instance 1 and index 164790
# Went into else of instance 0 and index 36330
# Went into else of instance 3 and index 3036170
# Went into else of instance 0 and index 36340
# Went into else of instance 1 and index 164810
# Went into else of instance 5 and index 7372320
# Went into else of instance 4 and index 5727690
# Went into else of instance 5 and index 7372330
# Went into else of instance 2 and index 444140
# Went into else of instance 1 and index 164820
# Went into else of instance 0 and index 36350
# Went into else of instance 2 and index 444150
# Went into else of instance 1 and index 164840
# Went into else of instance 2 and index 444160
# Went into else of instance 0 and index 36360
# Went into else of instance 5 and index 7372360
# Went into else of instance 2 and index 444170
# Went into else of instance 1 and index 164860
# Went into else of instance 3 and index 3036680
# Went into else of instance 0 and index 36380
# Went into else of instance 3 and index 3036890
# Went into else of instance 2 and index 444210
# Went into else of instance 1 and index 164870
# Went into else of instance 0 and index 36390
# Went into else of instance 1 and index 164880
# Went into else of instance 1 and index 164890
# Went into else of instance 0 and index 36400
# Went into else of instance 2 and index 444240
# The length of data for 0 and index 36400 is 35122
# Went into else of instance 4 and index 5728190
# Went into else of instance 4 and index 5728220
# Went into else of instance 0 and index 36420
# Went into else of instance 3 and index 3037880
# Went into else of instance 1 and index 164930
# Went into else of instance 3 and index 3038310
# Went into else of instance 1 and index 164950
# Went into else of instance 0 and index 36440
# Went into else of instance 1 and index 164960
# Went into else of instance 4 and index 5728440
# Went into else of instance 3 and index 3038650
# Went into else of instance 0 and index 36460
# there was a major exception
# there was a major exception
# there was a major exception

# %%
from all_processes.update_movie_data import *

# %%
imdb_df = UpdateMovieData().get_latest_imdb()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [107], in <module>
# ----> 1 imdb_df = UpdateMovieData().get_latest_imdb()
#
# File ~/movie_project/all_processes/update_movie_data.py:16, in UpdateMovieData.get_latest_imdb(self)
#      14 def get_latest_imdb(self):
#      15     if self.imdb_file_not_updated():
# ---> 16         soup = self.go_to_imdb_page()
#      17         links = self.get_all_links(soup)
#      18         self.download_all_links(links)
#
# File ~/movie_project/all_processes/update_movie_data.py:51, in UpdateMovieData.go_to_imdb_page(self)
#      50 def go_to_imdb_page(self):
# ---> 51     return get_soup_url(self.imdb_data_url)
#
# NameError: name 'get_soup_url' is not defined

# %%
for num in range(10):
    try:
        run_instances_okru_scraper(9, imdb_df)
    except:
        print("there was a major exception")
# Out:
# /var/folders/z9/ml790yl90yj8nyc5j320wb4w0000gn/T/ipykernel_1520/2424474536.py:4: DtypeWarning: Columns (3,4,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfs.append(pd.read_csv(okru_progress_path))
# Test 0 started!
# Test 1 started!
# Test 2 started!
# Test 3 started!
# Test 4 started!
# Test 5 started!
# Test 6 started!
# Test 7 started!
# Test 8 started!
# /var/folders/z9/ml790yl90yj8nyc5j320wb4w0000gn/T/ipykernel_1520/3168418098.py:7: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   return webdriver.Chrome(executable_path=CHROMEDRIVER_PATH, chrome_options=options)
# /var/folders/z9/ml790yl90yj8nyc5j320wb4w0000gn/T/ipykernel_1520/3168418098.py:7: DeprecationWarning: use options instead of chrome_options
#   return webdriver.Chrome(executable_path=CHROMEDRIVER_PATH, chrome_options=options)
# on default page if
# Went into else of instance 2 and index 399360
# Went into else of instance 2 and index 399380
# Went into else of instance 4 and index 3484690
# Went into else of instance 4 and index 3484850
# Went into else of instance 2 and index 399390
# Went into else of instance 2 and index 399400
# The length of data for 2 and index 399400 is 92
# on default page if
# Went into else of instance 2 and index 399510
# Went into else of instance 4 and index 3485320
# on default page if
# on default page if
# Went into else of instance 2 and index 399550
# Went into else of instance 2 and index 399560
# Went into else of instance 4 and index 3485500
# The length of data for 4 and index 3485500 is 121
# Went into else of instance 4 and index 3485540
# on default page if
# Went into else of instance 4 and index 3485620
# on default page if
# on default page if

# %%
from common_methods import *

# %%
# driver = get_driver()
# tconst = list(filter(has_some_data, all_data))[-1][0]["tconst"]
# first_index = imdb_df.loc[imdb_df["tconst"] == tconst].index[0]
okru_df = pd.read_csv("/Users/timdunn/Desktop/okru_progress.csv")
relevant_df = imdb_df.loc[~(imdb_df["runtimeMinutes"] == "\\N") & ~(imdb_df["tconst"].isin(okru_df["tconst"]))]
for index, row in relevant_df.iterrows():
    next_data = get_movie_search_results(driver, row["primaryTitle"], row["startYear"], row["tconst"], okru_url, other_data)
    other_data.append(next_data) 
    if (index % 100 == 0):
        pd.concat([okru_df, pd.DataFrame(data=convert_data(other_data))]).drop_duplicates().to_csv(
            "/Users/timdunn/Desktop/okru_progress.csv", index=False)

# %%
"/Users/timdunn/Desktop/okru_checkpoints/"

# %%
driver = get_driver()

# %%
go_to_startpage(driver, okru_url)

# %%
close_popup(driver)

# %%
element = driver.find_element(By.CLASS_NAME, "wrap-input__414z3")

# %%
element = driver.find_element(By.CLASS_NAME, "wrap-input__414z3")
button_element = element.find_element(By.TAG_NAME, "button")

# %%
video_search(driver).send_keys("some example")

# %%
button_element.click()

# %%
driver.quit()

# %%
pd.concat([okru_df, pd.DataFrame(data=convert_data(other_data))]).drop_duplicates().to_csv("/Users/timdunn/Desktop/okru_progress.csv", index=False)

# %%
<button type="button" class="button__pe9qo button-core-container__0ej09 squared-button__qz82p"><span class="button-core__0ej09 __size-m__0ej09 __wide__0ej09 squared-button-core__qz82p"><span class="content__0ej09">Search</span><span class="spinner__0ej09"><div class="spinner__paevy __size-20__paevy">
<div class="el__paevy"></div></div></span></span></button>

# %%
other_data[-5:]

# %%
filter(lambda data: data != "pending")

# %%
some_data = all_data[len(all_data) > 0]

# %%
len(all_data)

# %%
all_data[-100:]

# %%
def has_some_data(data):
    try:
        return len(data) > 0
    except:
        return False

# %%
all_data[[data != None for data in all_data]]

# %%
filtering = [data != None for data in all_data]
all_data[filtering]

# %%
some_data = list(filter(has_some_data, all_data))

# %%
some_data = flatten(some_data)

# %%
right_data = list(filter(lambda data: type(data) == dict, some_data))

# %%
len(right_data)

# %%
pd.DataFrame(data=right_data).to_csv("/Users/timdunn/Desktop/okru_progress.csv", index=False)

# %%
all_data[len(all_data) > 0]

# %%
imdb_df.loc[~(imdb_df["runtimeMinutes"] == "\\N")]

# %%
def update_tconst(movie_hash, row):
    movie_hash["tconst"] = row["tconst"]
    return movie_hash

# %%
def update_all_tconst(movie_hashes, row):
    return [update_tconst(movie_hash, row) for movie_hash in movie_hashes]

# %%
def flatten(some_list):
    return [item for sublist in some_list for item in sublist]
