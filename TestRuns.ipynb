# %%
from scraping.okru_scraper import *

# %%
from all_processes.load_yaml_vars import *

# %%
yaml_vars = LoadYamlVars("/Users/timdunn/movie_project/all_processes/movie_configuration.yaml")

# %%
okru_scraper = ScrapeAllImdb(7, yaml_vars.imdb_directory, yaml_vars.chromedriver_path,
                                                  yaml_vars.get_scraper_progress_path(OkruScraper), 
              OkruScraper, yaml_vars.get_scraping_directory(OkruScraper),
                                                  tconst_path=yaml_vars.get_scraper_tconst_path(OkruScraper))

# .run_instances_scraper()

# %%
okru_scraper.run_instances_scraper()
# Out:
# Test 0 started!
# Test 1 started!
# Test 2 started!
# Test 3 started!
# Test 4 started!
# Test 5 started!
# Test 6 started!
# Went into else of instance 0 and index 1170
# Went into else of instance 2 and index 400150
# Went into else of instance 1 and index 215120
# Went into else of instance 4 and index 679820
# Went into else of instance 6 and index 921510
# Went into else of instance 5 and index 804590
# Went into else of instance 6 and index 921520
# Went into else of instance 4 and index 679830
# Went into else of instance 3 and index 549700
# The length of data for 3 and index 549700 is 52
# Went into else of instance 5 and index 804600
# Went into else of instance 2 and index 400160
# The length of data for 5 and index 804600 is 419
# Went into else of instance 5 and index 804610
# Went into else of instance 2 and index 400170
# Went into else of instance 1 and index 215140
# Went into else of instance 5 and index 804620
# Went into else of instance 6 and index 921530
# ...

# %%
for num in range(10):
    try:
        okru_scraper.run_instances_scraper()
    except:
        print("there was a major exception")
# Out:
# Test 0 started!
# Test 1 started!
# Test 2 started!
# Test 3 started!
# Test 4 started!
# Test 5 started!
# Test 6 started!
# Went into else of instance 2 and index 400150
# Went into else of instance 0 and index 1170
# Went into else of instance 1 and index 215120
# Went into else of instance 4 and index 679820
# Went into else of instance 6 and index 921510
# Went into else of instance 5 and index 804590
# Went into else of instance 6 and index 921520
# Went into else of instance 3 and index 549700
# Went into else of instance 4 and index 679830
# The length of data for 3 and index 549700 is 75
# Went into else of instance 5 and index 804600
# Went into else of instance 2 and index 400160
# The length of data for 5 and index 804600 is 420
# Went into else of instance 5 and index 804610
# Went into else of instance 2 and index 400170
# Went into else of instance 1 and index 215140
# Went into else of instance 5 and index 804620
# Went into else of instance 1 and index 215150
# ...
